# %% [markdown]
# <a href="https://colab.research.google.com/github/Francho03/Praca-licencjacka/blob/main/codes/dane_korelujace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# drive.flush_and_unmount()

# %%
def polacz(*datasets):


    return pd.concat(datasets, ignore_index=True)

# %%
columns_names=["kod","pow","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"]

# %% [markdown]
# # Bezrobocie

# %%
bezrobocie = pd.read_excel(
    "/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/Bezrobotni_ogolem.xlsx",
    sheet_name="TABLICA",
    header=None,
    skiprows=4,
    names=columns_names,
    dtype={"kod": str}
)

# %%
bezrobocie_2014 = bezrobocie.iloc[:, [0,1,2]]
bezrobocie_2014["rok"] = 2014
bezrobocie_2014 = bezrobocie_2014.iloc[:, [0,1,3,2]]
bezrobocie_2014.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2014['kod']=bezrobocie_2014['kod'].astype(str)

bezrobocie_2015 = bezrobocie.iloc[:, [0,1,3]]
bezrobocie_2015["rok"] = 2015
bezrobocie_2015 = bezrobocie_2015.iloc[:, [0,1,3,2]]
bezrobocie_2015.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2015['kod']=bezrobocie_2015['kod'].astype(str)

bezrobocie_2016 = bezrobocie.iloc[:, [0,1,4]]
bezrobocie_2016["rok"] = 2016
bezrobocie_2016 = bezrobocie_2016.iloc[:, [0,1,3,2]]
bezrobocie_2016.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2016['kod']=bezrobocie_2016['kod'].astype(str)

bezrobocie_2017 = bezrobocie.iloc[:, [0,1,5]]
bezrobocie_2017["rok"] = 2017
bezrobocie_2017 = bezrobocie_2017.iloc[:, [0,1,3,2]]
bezrobocie_2017.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2017['kod']=bezrobocie_2017['kod'].astype(str)

bezrobocie_2018 = bezrobocie.iloc[:, [0,1,6]]
bezrobocie_2018["rok"] = 2018
bezrobocie_2018 = bezrobocie_2018.iloc[:, [0,1,3,2]]
bezrobocie_2018.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2018['kod']=bezrobocie_2018['kod'].astype(str)

bezrobocie_2019 = bezrobocie.iloc[:, [0,1,7]]
bezrobocie_2019["rok"] = 2019
bezrobocie_2019 = bezrobocie_2019.iloc[:, [0,1,3,2]]
bezrobocie_2019.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2019['kod']=bezrobocie_2019['kod'].astype(str)

bezrobocie_2020 = bezrobocie.iloc[:, [0,1,8]]
bezrobocie_2020["rok"] = 2020
bezrobocie_2020 = bezrobocie_2020.iloc[:, [0,1,3,2]]
bezrobocie_2020.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2020['kod']=bezrobocie_2020['kod'].astype(str)

bezrobocie_2021 = bezrobocie.iloc[:, [0,1,9]]
bezrobocie_2021["rok"] = 2021
bezrobocie_2021 = bezrobocie_2021.iloc[:, [0,1,3,2]]
bezrobocie_2021.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2021['kod']=bezrobocie_2021['kod'].astype(str)

bezrobocie_2022 = bezrobocie.iloc[:, [0,1,10]]
bezrobocie_2022["rok"] = 2022
bezrobocie_2022 = bezrobocie_2022.iloc[:, [0,1,3,2]]
bezrobocie_2022.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2022['kod']=bezrobocie_2022['kod'].astype(str)

bezrobocie_2023 = bezrobocie.iloc[:, [0,1,11]]
bezrobocie_2023["rok"] = 2023
bezrobocie_2023 = bezrobocie_2023.iloc[:, [0,1,3,2]]
bezrobocie_2023.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
bezrobocie_2023['kod']=bezrobocie_2023['kod'].astype(str)
# Out:
# <ipython-input-8-c1047072de99>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2014["rok"] = 2014
# <ipython-input-8-c1047072de99>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2015["rok"] = 2015
# <ipython-input-8-c1047072de99>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2016["rok"] = 2016
# <ipython-input-8-c1047072de99>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2017["rok"] = 2017
# <ipython-input-8-c1047072de99>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2018["rok"] = 2018
# <ipython-input-8-c1047072de99>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2019["rok"] = 2019
# <ipython-input-8-c1047072de99>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2020["rok"] = 2020
# <ipython-input-8-c1047072de99>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2021["rok"] = 2021
# <ipython-input-8-c1047072de99>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2022["rok"] = 2022
# <ipython-input-8-c1047072de99>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2023["rok"] = 2023

# %%
bezrobocie_full = polacz(bezrobocie_2023
   ,bezrobocie_2022,bezrobocie_2021,
bezrobocie_2020, bezrobocie_2019,
bezrobocie_2018,bezrobocie_2017,
bezrobocie_2016,bezrobocie_2015,bezrobocie_2014

)

# %%
bezrobocie_full
# Out:
#           kod                    pow   rok  liczba_bezrobotnych
# 0     0201000   Powiat bolesławiecki  2023                  886
# 1     0202000  Powiat dzierżoniowski  2023                 1593
# 2     0203000       Powiat głogowski  2023                 1761
# 3     0204000        Powiat górowski  2023                 1302
# 4     0205000        Powiat jaworski  2023                 1550
# ...       ...                    ...   ...                  ...
# 3795  3217000         Powiat wałecki  2014                 2859
# 3796  3218000         Powiat łobeski  2014                 2836
# 3797  3261000     Powiat m. Koszalin  2014                 5053
# 3798  3262000     Powiat m. Szczecin  2014                16195
# 3799  3263000  Powiat m. Świnoujście  2014                 1175
#
# [3800 rows x 4 columns]

# %%
bezrobocie_full["liczba_bezrobotnych"]=bezrobocie_full["liczba_bezrobotnych"].astype(int)
bezrobocie_full["kod"]=bezrobocie_full['kod'].astype(str)
bezrobocie_full
# Out:
#           kod                    pow   rok  liczba_bezrobotnych
# 0     0201000   Powiat bolesławiecki  2023                  886
# 1     0202000  Powiat dzierżoniowski  2023                 1593
# 2     0203000       Powiat głogowski  2023                 1761
# 3     0204000        Powiat górowski  2023                 1302
# 4     0205000        Powiat jaworski  2023                 1550
# ...       ...                    ...   ...                  ...
# 3795  3217000         Powiat wałecki  2014                 2859
# 3796  3218000         Powiat łobeski  2014                 2836
# 3797  3261000     Powiat m. Koszalin  2014                 5053
# 3798  3262000     Powiat m. Szczecin  2014                16195
# 3799  3263000  Powiat m. Świnoujście  2014                 1175
#
# [3800 rows x 4 columns]

# %%
bezrobocie_dlugotrwale= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/bezrobotni_dlugotrwale.xlsx",sheet_name="TABLICA", header= None, skiprows=4, names=columns_names,  dtype={"kod": str}
)

# %%
bezrobocie_dlugotrwale_2014 = bezrobocie_dlugotrwale.iloc[:, [0,1,2]]
bezrobocie_dlugotrwale_2014["rok"] = 2014
bezrobocie_dlugotrwale_2014 = bezrobocie_dlugotrwale_2014.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2014.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2015 = bezrobocie_dlugotrwale.iloc[:, [0,1,3]]
bezrobocie_dlugotrwale_2015["rok"] = 2015
bezrobocie_dlugotrwale_2015 = bezrobocie_dlugotrwale_2015.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2015.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2016 = bezrobocie_dlugotrwale.iloc[:, [0,1,4]]
bezrobocie_dlugotrwale_2016["rok"] = 2016
bezrobocie_dlugotrwale_2016 = bezrobocie_dlugotrwale_2016.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2016.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2017 =bezrobocie_dlugotrwale.iloc[:, [0,1,5]]
bezrobocie_dlugotrwale_2017["rok"] = 2017
bezrobocie_dlugotrwale_2017 = bezrobocie_dlugotrwale_2017.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2017.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2018 = bezrobocie_dlugotrwale.iloc[:, [0,1,6]]
bezrobocie_dlugotrwale_2018["rok"] = 2018
bezrobocie_dlugotrwale_2018 = bezrobocie_dlugotrwale_2018.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2018.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2019 = bezrobocie_dlugotrwale.iloc[:, [0,1,7]]
bezrobocie_dlugotrwale_2019["rok"] = 2019
bezrobocie_dlugotrwale_2019 = bezrobocie_dlugotrwale_2019.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2019.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2020 = bezrobocie_dlugotrwale.iloc[:, [0,1,8]]
bezrobocie_dlugotrwale_2020["rok"] = 2020
bezrobocie_dlugotrwale_2020 = bezrobocie_dlugotrwale_2020.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2020.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2021 = bezrobocie_dlugotrwale.iloc[:, [0,1,9]]
bezrobocie_dlugotrwale_2021["rok"] = 2021
bezrobocie_dlugotrwale_2021 = bezrobocie_dlugotrwale_2021.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2021.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2022 = bezrobocie_dlugotrwale.iloc[:, [0,1,10]]
bezrobocie_dlugotrwale_2022["rok"] = 2022
bezrobocie_dlugotrwale_2022 = bezrobocie_dlugotrwale_2022.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2022.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]

bezrobocie_dlugotrwale_2023 = bezrobocie_dlugotrwale.iloc[:, [0,1,11]]
bezrobocie_dlugotrwale_2023["rok"] = 2023
bezrobocie_dlugotrwale_2023 = bezrobocie_dlugotrwale_2023.iloc[:, [0,1,3,2]]
bezrobocie_dlugotrwale_2023.columns = ["kod", "pow", "rok", "liczba_bezrobotnych_dlugotrwale"]
# Out:
# <ipython-input-13-36add53c9a5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2014["rok"] = 2014
# <ipython-input-13-36add53c9a5b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2015["rok"] = 2015
# <ipython-input-13-36add53c9a5b>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2016["rok"] = 2016
# <ipython-input-13-36add53c9a5b>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2017["rok"] = 2017
# <ipython-input-13-36add53c9a5b>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2018["rok"] = 2018
# <ipython-input-13-36add53c9a5b>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2019["rok"] = 2019
# <ipython-input-13-36add53c9a5b>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2020["rok"] = 2020
# <ipython-input-13-36add53c9a5b>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2021["rok"] = 2021
# <ipython-input-13-36add53c9a5b>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2022["rok"] = 2022
# <ipython-input-13-36add53c9a5b>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_dlugotrwale_2023["rok"] = 2023

# %%
bezrobocie_dlugotrwale_full = polacz(bezrobocie_dlugotrwale_2023
   ,bezrobocie_dlugotrwale_2022,bezrobocie_dlugotrwale_2021,
bezrobocie_dlugotrwale_2020, bezrobocie_dlugotrwale_2019,
bezrobocie_dlugotrwale_2018,bezrobocie_dlugotrwale_2017,
bezrobocie_dlugotrwale_2016,bezrobocie_dlugotrwale_2015,bezrobocie_dlugotrwale_2014

)

# %%
bezrobocie_dlugotrwale_full["liczba_bezrobotnych_dlugotrwale"]=bezrobocie_dlugotrwale_full["liczba_bezrobotnych_dlugotrwale"].astype(int)
bezrobocie_dlugotrwale_full["kod"]=bezrobocie_dlugotrwale_full['kod'].astype(str)
bezrobocie_dlugotrwale_full
# Out:
#           kod                    pow   rok  liczba_bezrobotnych_dlugotrwale
# 0     0201000   Powiat bolesławiecki  2023                              229
# 1     0202000  Powiat dzierżoniowski  2023                              541
# 2     0203000       Powiat głogowski  2023                              866
# 3     0204000        Powiat górowski  2023                              694
# 4     0205000        Powiat jaworski  2023                              845
# ...       ...                    ...   ...                              ...
# 3795  3217000         Powiat wałecki  2014                             1625
# 3796  3218000         Powiat łobeski  2014                             1693
# 3797  3261000     Powiat m. Koszalin  2014                             2857
# 3798  3262000     Powiat m. Szczecin  2014                             9285
# 3799  3263000  Powiat m. Świnoujście  2014                              439
#
# [3800 rows x 4 columns]

# %%
bezrobocie_odsetek = pd.merge(
    bezrobocie_dlugotrwale_full,
    bezrobocie_full,
    on=["kod", "rok", "pow"],
    suffixes=('_dlugotrwale', '_ogolnie')
)

# %%
bezrobocie_odsetek["odsetek_bezrobotnych_dlugotrwalych"] = (
    bezrobocie_odsetek["liczba_bezrobotnych_dlugotrwale"] / bezrobocie_odsetek["liczba_bezrobotnych"]
).round(4)

# %%
bezrobocie_odsetek=bezrobocie_odsetek.drop(columns=["liczba_bezrobotnych_dlugotrwale","liczba_bezrobotnych"])
bezrobocie_odsetek
# Out:
#           kod                    pow   rok  odsetek_bezrobotnych_dlugotrwalych
# 0     0201000   Powiat bolesławiecki  2023                              0.2585
# 1     0202000  Powiat dzierżoniowski  2023                              0.3396
# 2     0203000       Powiat głogowski  2023                              0.4918
# 3     0204000        Powiat górowski  2023                              0.5330
# 4     0205000        Powiat jaworski  2023                              0.5452
# ...       ...                    ...   ...                                 ...
# 3795  3217000         Powiat wałecki  2014                              0.5684
# 3796  3218000         Powiat łobeski  2014                              0.5970
# 3797  3261000     Powiat m. Koszalin  2014                              0.5654
# 3798  3262000     Powiat m. Szczecin  2014                              0.5733
# 3799  3263000  Powiat m. Świnoujście  2014                              0.3736
#
# [3800 rows x 4 columns]

# %% [markdown]
# # Wynagrodzenie

# %%
wynagrodzenie= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/Przeciętne miesięczne wynagrodzenia brutto.xlsx",sheet_name="TABLICA", header= None, skiprows=3, names=columns_names,  dtype={"kod": str}
)

# %%
wynagrodzenie_2014 = wynagrodzenie.iloc[:, [0,1,2]]
wynagrodzenie_2014["rok"] = 2014
wynagrodzenie_2014 = wynagrodzenie_2014.iloc[:, [0,1,3,2]]
wynagrodzenie_2014.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2015 = wynagrodzenie.iloc[:, [0,1,3]]
wynagrodzenie_2015["rok"] = 2015
wynagrodzenie_2015 = wynagrodzenie_2015.iloc[:, [0,1,3,2]]
wynagrodzenie_2015.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2016 = wynagrodzenie.iloc[:, [0,1,4]]
wynagrodzenie_2016["rok"] = 2016
wynagrodzenie_2016 = wynagrodzenie_2016.iloc[:, [0,1,3,2]]
wynagrodzenie_2016.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2017 = wynagrodzenie.iloc[:, [0,1,5]]
wynagrodzenie_2017["rok"] = 2017
wynagrodzenie_2017 = wynagrodzenie_2017.iloc[:, [0,1,3,2]]
wynagrodzenie_2017.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2018 = wynagrodzenie.iloc[:, [0,1,6]]
wynagrodzenie_2018["rok"] = 2018
wynagrodzenie_2018 = wynagrodzenie_2018.iloc[:, [0,1,3,2]]
wynagrodzenie_2018.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2019 = wynagrodzenie.iloc[:, [0,1,7]]
wynagrodzenie_2019["rok"] = 2019
wynagrodzenie_2019 = wynagrodzenie_2019.iloc[:, [0,1,3,2]]
wynagrodzenie_2019.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2020 = wynagrodzenie.iloc[:, [0,1,8]]
wynagrodzenie_2020["rok"] = 2020
wynagrodzenie_2020 = wynagrodzenie_2020.iloc[:, [0,1,3,2]]
wynagrodzenie_2020.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2021 = wynagrodzenie.iloc[:, [0,1,9]]
wynagrodzenie_2021["rok"] = 2021
wynagrodzenie_2021 = wynagrodzenie_2021.iloc[:, [0,1,3,2]]
wynagrodzenie_2021.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2022 = wynagrodzenie.iloc[:, [0,1,10]]
wynagrodzenie_2022["rok"] = 2022
wynagrodzenie_2022 = wynagrodzenie_2022.iloc[:, [0,1,3,2]]
wynagrodzenie_2022.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2023 = wynagrodzenie.iloc[:, [0,1,11]]
wynagrodzenie_2023["rok"] = 2023
wynagrodzenie_2023 = wynagrodzenie_2023.iloc[:, [0,1,3,2]]
wynagrodzenie_2023.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]
# Out:
# <ipython-input-20-3b85d782a8db>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2014["rok"] = 2014
# <ipython-input-20-3b85d782a8db>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2015["rok"] = 2015
# <ipython-input-20-3b85d782a8db>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2016["rok"] = 2016
# <ipython-input-20-3b85d782a8db>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2017["rok"] = 2017
# <ipython-input-20-3b85d782a8db>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2018["rok"] = 2018
# <ipython-input-20-3b85d782a8db>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2019["rok"] = 2019
# <ipython-input-20-3b85d782a8db>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2020["rok"] = 2020
# <ipython-input-20-3b85d782a8db>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2021["rok"] = 2021
# <ipython-input-20-3b85d782a8db>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2022["rok"] = 2022
# <ipython-input-20-3b85d782a8db>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2023["rok"] = 2023

# %%
wynagrodzenie_full = polacz(wynagrodzenie_2023
   ,wynagrodzenie_2022,wynagrodzenie_2021,
wynagrodzenie_2020, wynagrodzenie_2019,
wynagrodzenie_2018,wynagrodzenie_2017,
wynagrodzenie_2016,wynagrodzenie_2015,wynagrodzenie_2014

)

# %%
wynagrodzenie_full["wielkosc_wynagrodzenia"]=wynagrodzenie_full["wielkosc_wynagrodzenia"].astype(int)
wynagrodzenie_full["kod"]=wynagrodzenie_full['kod'].astype(str)
wynagrodzenie_full
# Out:
#           kod                    pow   rok  wielkosc_wynagrodzenia
# 0     0201000   Powiat bolesławiecki  2023                    6871
# 1     0202000  Powiat dzierżoniowski  2023                    6459
# 2     0203000       Powiat głogowski  2023                    6660
# 3     0204000        Powiat górowski  2023                    6060
# 4     0205000        Powiat jaworski  2023                    7059
# ...       ...                    ...   ...                     ...
# 3795  3217000         Powiat wałecki  2014                    3336
# 3796  3218000         Powiat łobeski  2014                    3289
# 3797  3261000     Powiat m. Koszalin  2014                    3568
# 3798  3262000     Powiat m. Szczecin  2014                    4176
# 3799  3263000  Powiat m. Świnoujście  2014                    4127
#
# [3800 rows x 4 columns]

# %% [markdown]
# # Malzenstwa i rozwody

# %%
malzenstwa= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/malzenstwa.xlsx",sheet_name="TABLICA", header= None, skiprows=4, names=columns_names,  dtype={"kod": str}
)

# %%
malzenstwa_2014 = malzenstwa.iloc[:, [0,1,2]]
malzenstwa_2014["rok"] = 2014
malzenstwa_2014 = malzenstwa_2014.iloc[:, [0,1,3,2]]
malzenstwa_2014.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2015 = malzenstwa.iloc[:, [0,1,3]]
malzenstwa_2015["rok"] = 2015
malzenstwa_2015 = malzenstwa_2015.iloc[:, [0,1,3,2]]
malzenstwa_2015.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2016 = malzenstwa.iloc[:, [0,1,4]]
malzenstwa_2016["rok"] = 2016
malzenstwa_2016 = malzenstwa_2016.iloc[:, [0,1,3,2]]
malzenstwa_2016.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2017 = malzenstwa.iloc[:, [0,1,5]]
malzenstwa_2017["rok"] = 2017
malzenstwa_2017 = malzenstwa_2017.iloc[:, [0,1,3,2]]
malzenstwa_2017.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2018 = malzenstwa.iloc[:, [0,1,6]]
malzenstwa_2018["rok"] = 2018
malzenstwa_2018 = malzenstwa_2018.iloc[:, [0,1,3,2]]
malzenstwa_2018.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2019 = malzenstwa.iloc[:, [0,1,7]]
malzenstwa_2019["rok"] = 2019
malzenstwa_2019 = malzenstwa_2019.iloc[:, [0,1,3,2]]
malzenstwa_2019.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2020 = malzenstwa.iloc[:, [0,1,8]]
malzenstwa_2020["rok"] = 2020
malzenstwa_2020 = malzenstwa_2020.iloc[:, [0,1,3,2]]
malzenstwa_2020.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2021 = malzenstwa.iloc[:, [0,1,9]]
malzenstwa_2021["rok"] = 2021
malzenstwa_2021 = malzenstwa_2021.iloc[:, [0,1,3,2]]
malzenstwa_2021.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2022 = malzenstwa.iloc[:, [0,1,10]]
malzenstwa_2022["rok"] = 2022
malzenstwa_2022 = malzenstwa_2022.iloc[:, [0,1,3,2]]
malzenstwa_2022.columns = ["kod", "pow", "rok", "liczba_malzenstw"]

malzenstwa_2023 = malzenstwa.iloc[:, [0,1,11]]
malzenstwa_2023["rok"] = 2023
malzenstwa_2023 = malzenstwa_2023.iloc[:, [0,1,3,2]]
malzenstwa_2023.columns = ["kod", "pow", "rok", "liczba_malzenstw"]
# Out:
# <ipython-input-24-905b82422893>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2014["rok"] = 2014
# <ipython-input-24-905b82422893>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2015["rok"] = 2015
# <ipython-input-24-905b82422893>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2016["rok"] = 2016
# <ipython-input-24-905b82422893>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2017["rok"] = 2017
# <ipython-input-24-905b82422893>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2018["rok"] = 2018
# <ipython-input-24-905b82422893>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2019["rok"] = 2019
# <ipython-input-24-905b82422893>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2020["rok"] = 2020
# <ipython-input-24-905b82422893>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2021["rok"] = 2021
# <ipython-input-24-905b82422893>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2022["rok"] = 2022
# <ipython-input-24-905b82422893>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malzenstwa_2023["rok"] = 2023

# %%
malzenstwa_full = polacz(malzenstwa_2023
   ,malzenstwa_2022,malzenstwa_2021,
malzenstwa_2020, malzenstwa_2019,
malzenstwa_2018,malzenstwa_2017,
malzenstwa_2016,malzenstwa_2015,malzenstwa_2014

)

# %%
malzenstwa_full["liczba_malzenstw"]=malzenstwa_full["liczba_malzenstw"].astype(int)
malzenstwa_full["kod"]=malzenstwa_full['kod'].astype(str)
malzenstwa_full
# Out:
#           kod                    pow   rok  liczba_malzenstw
# 0     0201000   Powiat bolesławiecki  2023               359
# 1     0202000  Powiat dzierżoniowski  2023               290
# 2     0203000       Powiat głogowski  2023               358
# 3     0204000        Powiat górowski  2023               121
# 4     0205000        Powiat jaworski  2023               171
# ...       ...                    ...   ...               ...
# 3795  3217000         Powiat wałecki  2014               285
# 3796  3218000         Powiat łobeski  2014               192
# 3797  3261000     Powiat m. Koszalin  2014               518
# 3798  3262000     Powiat m. Szczecin  2014              1837
# 3799  3263000  Powiat m. Świnoujście  2014               210
#
# [3800 rows x 4 columns]

# %%
rozwody= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/Rozwody.xlsx",sheet_name="TABLICA", header= None, skiprows=4, names=columns_names,  dtype={"kod": str}
)

# %%
rozwody_2014 = rozwody.iloc[:, [0,1,2]]
rozwody_2014["rok"] = 2014
rozwody_2014 = rozwody_2014.iloc[:, [0,1,3,2]]
rozwody_2014.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2015 = rozwody.iloc[:, [0,1,3]]
rozwody_2015["rok"] = 2015
rozwody_2015 = rozwody_2015.iloc[:, [0,1,3,2]]
rozwody_2015.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2016 = rozwody.iloc[:, [0,1,4]]
rozwody_2016["rok"] = 2016
rozwody_2016 = rozwody_2016.iloc[:, [0,1,3,2]]
rozwody_2016.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2017 = rozwody.iloc[:, [0,1,5]]
rozwody_2017["rok"] = 2017
rozwody_2017 = rozwody_2017.iloc[:, [0,1,3,2]]
rozwody_2017.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2018 = rozwody.iloc[:, [0,1,6]]
rozwody_2018["rok"] = 2018
rozwody_2018 = rozwody_2018.iloc[:, [0,1,3,2]]
rozwody_2018.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2019 = rozwody.iloc[:, [0,1,7]]
rozwody_2019["rok"] = 2019
rozwody_2019 = rozwody_2019.iloc[:, [0,1,3,2]]
rozwody_2019.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2020 = rozwody.iloc[:, [0,1,8]]
rozwody_2020["rok"] = 2020
rozwody_2020 = rozwody_2020.iloc[:, [0,1,3,2]]
rozwody_2020.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2021 = rozwody.iloc[:, [0,1,9]]
rozwody_2021["rok"] = 2021
rozwody_2021 = rozwody_2021.iloc[:, [0,1,3,2]]
rozwody_2021.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2022 = rozwody.iloc[:, [0,1,10]]
rozwody_2022["rok"] = 2022
rozwody_2022 = rozwody_2022.iloc[:, [0,1,3,2]]
rozwody_2022.columns = ["kod", "pow", "rok", "liczba_rozwodow"]

rozwody_2023 = rozwody.iloc[:, [0,1,11]]
rozwody_2023["rok"] = 2023
rozwody_2023 = rozwody_2023.iloc[:, [0,1,3,2]]
rozwody_2023.columns = ["kod", "pow", "rok", "liczba_rozwodow"]
# Out:
# <ipython-input-28-2e12cf6f2c6e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2014["rok"] = 2014
# <ipython-input-28-2e12cf6f2c6e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2015["rok"] = 2015
# <ipython-input-28-2e12cf6f2c6e>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2016["rok"] = 2016
# <ipython-input-28-2e12cf6f2c6e>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2017["rok"] = 2017
# <ipython-input-28-2e12cf6f2c6e>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2018["rok"] = 2018
# <ipython-input-28-2e12cf6f2c6e>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2019["rok"] = 2019
# <ipython-input-28-2e12cf6f2c6e>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2020["rok"] = 2020
# <ipython-input-28-2e12cf6f2c6e>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2021["rok"] = 2021
# <ipython-input-28-2e12cf6f2c6e>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2022["rok"] = 2022
# <ipython-input-28-2e12cf6f2c6e>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rozwody_2023["rok"] = 2023

# %%
rozwody_full = polacz(rozwody_2023
   ,rozwody_2022,rozwody_2021,
rozwody_2020, rozwody_2019,
rozwody_2018,rozwody_2017,
rozwody_2016,rozwody_2015,rozwody_2014

)

# %%
rozwody_full["liczba_rozwodow"]=rozwody_full["liczba_rozwodow"].astype(int)
rozwody_full["kod"]=rozwody_full['kod'].astype(str)
rozwody_full
# Out:
#           kod                    pow   rok  liczba_rozwodow
# 0     0201000   Powiat bolesławiecki  2023              141
# 1     0202000  Powiat dzierżoniowski  2023              144
# 2     0203000       Powiat głogowski  2023              135
# 3     0204000        Powiat górowski  2023               41
# 4     0205000        Powiat jaworski  2023               63
# ...       ...                    ...   ...              ...
# 3795  3217000         Powiat wałecki  2014               95
# 3796  3218000         Powiat łobeski  2014               62
# 3797  3261000     Powiat m. Koszalin  2014              247
# 3798  3262000     Powiat m. Szczecin  2014              886
# 3799  3263000  Powiat m. Świnoujście  2014              123
#
# [3800 rows x 4 columns]

# %%
rozwody_odsetek = pd.merge(
    rozwody_full,
    malzenstwa_full,
    on=["kod", "rok", "pow"],
)

# %%
rozwody_odsetek["odsetek_rozwodow"] = (
    rozwody_odsetek["liczba_rozwodow"] / rozwody_odsetek["liczba_malzenstw"]
).round(4)

# %%
rozwody_odsetek=rozwody_odsetek.drop(columns=["liczba_rozwodow","liczba_malzenstw"])
rozwody_odsetek
# Out:
#           kod                    pow   rok  odsetek_rozwodow
# 0     0201000   Powiat bolesławiecki  2023            0.3928
# 1     0202000  Powiat dzierżoniowski  2023            0.4966
# 2     0203000       Powiat głogowski  2023            0.3771
# 3     0204000        Powiat górowski  2023            0.3388
# 4     0205000        Powiat jaworski  2023            0.3684
# ...       ...                    ...   ...               ...
# 3795  3217000         Powiat wałecki  2014            0.3333
# 3796  3218000         Powiat łobeski  2014            0.3229
# 3797  3261000     Powiat m. Koszalin  2014            0.4768
# 3798  3262000     Powiat m. Szczecin  2014            0.4823
# 3799  3263000  Powiat m. Świnoujście  2014            0.5857
#
# [3800 rows x 4 columns]

# %% [markdown]
# #  zasoby mieszkaniowe wskaźniki

# %%
osoby_na_1_izbe= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/przecietna liczba osob na 1 izbe.xlsx",sheet_name="TABLICA", header= None, skiprows=3, names=columns_names,  dtype={"kod": str}
)

# %%
osoby_na_1_izbe_2014 = osoby_na_1_izbe.iloc[:, [0,1,2]]
osoby_na_1_izbe_2014["rok"] = 2014
osoby_na_1_izbe_2014 = osoby_na_1_izbe_2014.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2014.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2015 = osoby_na_1_izbe.iloc[:, [0,1,3]]
osoby_na_1_izbe_2015["rok"] = 2015
osoby_na_1_izbe_2015 = osoby_na_1_izbe_2015.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2015.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2016 = osoby_na_1_izbe.iloc[:, [0,1,4]]
osoby_na_1_izbe_2016["rok"] = 2016
osoby_na_1_izbe_2016 = osoby_na_1_izbe_2016.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2016.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2017 = osoby_na_1_izbe.iloc[:, [0,1,5]]
osoby_na_1_izbe_2017["rok"] = 2017
osoby_na_1_izbe_2017 = osoby_na_1_izbe_2017.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2017.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2018 = osoby_na_1_izbe.iloc[:, [0,1,6]]
osoby_na_1_izbe_2018["rok"] = 2018
osoby_na_1_izbe_2018 = osoby_na_1_izbe_2018.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2018.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2019 = osoby_na_1_izbe.iloc[:, [0,1,7]]
osoby_na_1_izbe_2019["rok"] = 2019
osoby_na_1_izbe_2019 = osoby_na_1_izbe_2019.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2019.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2020 = osoby_na_1_izbe.iloc[:, [0,1,8]]
osoby_na_1_izbe_2020["rok"] = 2020
osoby_na_1_izbe_2020 = osoby_na_1_izbe_2020.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2020.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2021 = osoby_na_1_izbe.iloc[:, [0,1,9]]
osoby_na_1_izbe_2021["rok"] = 2021
osoby_na_1_izbe_2021 = osoby_na_1_izbe_2021.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2021.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2022 = osoby_na_1_izbe.iloc[:, [0,1,10]]
osoby_na_1_izbe_2022["rok"] = 2022
osoby_na_1_izbe_2022 = osoby_na_1_izbe_2022.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2022.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]

osoby_na_1_izbe_2023 = osoby_na_1_izbe.iloc[:, [0,1,11]]
osoby_na_1_izbe_2023["rok"] = 2023
osoby_na_1_izbe_2023 = osoby_na_1_izbe_2023.iloc[:, [0,1,3,2]]
osoby_na_1_izbe_2023.columns = ["kod", "pow", "rok", "liczba_osob_na_1_izbe"]
# Out:
# <ipython-input-35-67dc7f31a4ec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2014["rok"] = 2014
# <ipython-input-35-67dc7f31a4ec>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2015["rok"] = 2015
# <ipython-input-35-67dc7f31a4ec>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2016["rok"] = 2016
# <ipython-input-35-67dc7f31a4ec>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2017["rok"] = 2017
# <ipython-input-35-67dc7f31a4ec>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2018["rok"] = 2018
# <ipython-input-35-67dc7f31a4ec>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2019["rok"] = 2019
# <ipython-input-35-67dc7f31a4ec>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2020["rok"] = 2020
# <ipython-input-35-67dc7f31a4ec>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2021["rok"] = 2021
# <ipython-input-35-67dc7f31a4ec>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2022["rok"] = 2022
# <ipython-input-35-67dc7f31a4ec>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   osoby_na_1_izbe_2023["rok"] = 2023

# %%
osoby_na_1_izbe_full = polacz(osoby_na_1_izbe_2023
   ,osoby_na_1_izbe_2022,osoby_na_1_izbe_2021,
osoby_na_1_izbe_2020, osoby_na_1_izbe_2019,
osoby_na_1_izbe_2018,osoby_na_1_izbe_2017,
osoby_na_1_izbe_2016,osoby_na_1_izbe_2015,osoby_na_1_izbe_2014

)

# %%
osoby_na_1_izbe_full["kod"]=osoby_na_1_izbe_full['kod'].astype(str)
osoby_na_1_izbe_full
# Out:
#           kod                    pow   rok  liczba_osob_na_1_izbe
# 0     0201000   Powiat bolesławiecki  2023                   0.61
# 1     0202000  Powiat dzierżoniowski  2023                   0.65
# 2     0203000       Powiat głogowski  2023                   0.65
# 3     0204000        Powiat górowski  2023                   0.64
# 4     0205000        Powiat jaworski  2023                   0.64
# ...       ...                    ...   ...                    ...
# 3795  3217000         Powiat wałecki  2014                   0.76
# 3796  3218000         Powiat łobeski  2014                   0.78
# 3797  3261000     Powiat m. Koszalin  2014                   0.67
# 3798  3262000     Powiat m. Szczecin  2014                   0.66
# 3799  3263000  Powiat m. Świnoujście  2014                   0.54
#
# [3800 rows x 4 columns]

# %%
powierzchnia_na_1_osobe= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/przecietna powierzchnia uzytkowa mieszkania na 1 osobe.xlsx",sheet_name="TABLICA", header= None, skiprows=3, names=columns_names,  dtype={"kod": str}
)

# %%
powierzchnia_na_1_osobe_2014 = powierzchnia_na_1_osobe.iloc[:, [0,1,2]]
powierzchnia_na_1_osobe_2014["rok"] = 2014
powierzchnia_na_1_osobe_2014 = powierzchnia_na_1_osobe_2014.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2014.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2015 = powierzchnia_na_1_osobe.iloc[:, [0,1,3]]
powierzchnia_na_1_osobe_2015["rok"] = 2015
powierzchnia_na_1_osobe_2015 = powierzchnia_na_1_osobe_2015.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2015.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2016 = powierzchnia_na_1_osobe.iloc[:, [0,1,4]]
powierzchnia_na_1_osobe_2016["rok"] = 2016
powierzchnia_na_1_osobe_2016 = powierzchnia_na_1_osobe_2016.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2016.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2017 = powierzchnia_na_1_osobe.iloc[:, [0,1,5]]
powierzchnia_na_1_osobe_2017["rok"] = 2017
powierzchnia_na_1_osobe_2017 = powierzchnia_na_1_osobe_2017.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2017.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2018 = powierzchnia_na_1_osobe.iloc[:, [0,1,6]]
powierzchnia_na_1_osobe_2018["rok"] = 2018
powierzchnia_na_1_osobe_2018 = powierzchnia_na_1_osobe_2018.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2018.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2019 = powierzchnia_na_1_osobe.iloc[:, [0,1,7]]
powierzchnia_na_1_osobe_2019["rok"] = 2019
powierzchnia_na_1_osobe_2019 = powierzchnia_na_1_osobe_2019.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2019.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2020 = powierzchnia_na_1_osobe.iloc[:, [0,1,8]]
powierzchnia_na_1_osobe_2020["rok"] = 2020
powierzchnia_na_1_osobe_2020 = powierzchnia_na_1_osobe_2020.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2020.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2021 = powierzchnia_na_1_osobe.iloc[:, [0,1,9]]
powierzchnia_na_1_osobe_2021["rok"] = 2021
powierzchnia_na_1_osobe_2021 = powierzchnia_na_1_osobe_2021.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2021.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2022 = powierzchnia_na_1_osobe.iloc[:, [0,1,10]]
powierzchnia_na_1_osobe_2022["rok"] = 2022
powierzchnia_na_1_osobe_2022 = powierzchnia_na_1_osobe_2022.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2022.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]

powierzchnia_na_1_osobe_2023 = powierzchnia_na_1_osobe.iloc[:, [0,1,11]]
powierzchnia_na_1_osobe_2023["rok"] = 2023
powierzchnia_na_1_osobe_2023 = powierzchnia_na_1_osobe_2023.iloc[:, [0,1,3,2]]
powierzchnia_na_1_osobe_2023.columns = ["kod", "pow", "rok", "przecietna_powierzchnia_mieszkania_na_1_osobe"]
# Out:
# <ipython-input-39-0492ff18f071>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2014["rok"] = 2014
# <ipython-input-39-0492ff18f071>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2015["rok"] = 2015
# <ipython-input-39-0492ff18f071>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2016["rok"] = 2016
# <ipython-input-39-0492ff18f071>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2017["rok"] = 2017
# <ipython-input-39-0492ff18f071>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2018["rok"] = 2018
# <ipython-input-39-0492ff18f071>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2019["rok"] = 2019
# <ipython-input-39-0492ff18f071>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2020["rok"] = 2020
# <ipython-input-39-0492ff18f071>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2021["rok"] = 2021
# <ipython-input-39-0492ff18f071>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2022["rok"] = 2022
# <ipython-input-39-0492ff18f071>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   powierzchnia_na_1_osobe_2023["rok"] = 2023

# %%
powierzchnia_na_1_osobe_full = polacz(powierzchnia_na_1_osobe_2023
   ,powierzchnia_na_1_osobe_2022,powierzchnia_na_1_osobe_2021,
powierzchnia_na_1_osobe_2020, powierzchnia_na_1_osobe_2019,
powierzchnia_na_1_osobe_2018,powierzchnia_na_1_osobe_2017,
powierzchnia_na_1_osobe_2016,powierzchnia_na_1_osobe_2015,powierzchnia_na_1_osobe_2014

)

# %%
# powierzchnia_na_1_osobe_full["przecietna_powierzchnia_mieszkania_na_1_osobe"]=powierzchnia_na_1_osobe_full["przecietna_powierzchnia_mieszkania_na_1_osobe"].astype(int)
powierzchnia_na_1_osobe_full["kod"]=powierzchnia_na_1_osobe_full['kod'].astype(str)
powierzchnia_na_1_osobe_full
# Out:
#           kod                    pow   rok  \
# 0     0201000   Powiat bolesławiecki  2023
# 1     0202000  Powiat dzierżoniowski  2023
# 2     0203000       Powiat głogowski  2023
# 3     0204000        Powiat górowski  2023
# 4     0205000        Powiat jaworski  2023
# ...       ...                    ...   ...
# 3795  3217000         Powiat wałecki  2014
# 3796  3218000         Powiat łobeski  2014
# 3797  3261000     Powiat m. Koszalin  2014
# 3798  3262000     Powiat m. Szczecin  2014
# 3799  3263000  Powiat m. Świnoujście  2014
#
#       przecietna_powierzchnia_mieszkania_na_1_osobe
# 0                                              32.4
# 1                                              28.7
# 2                                              27.9
# 3                                              30.2
# 4                                              29.9
# ...                                             ...
# 3795                                           24.0
# 3796                                           23.1
# 3797                                           26.3
# 3798                                           26.9
# 3799                                           32.8
#
# [3800 rows x 4 columns]

# %% [markdown]
#  # Spis powszechny:

# %% [markdown]
# ## mieszkania przepełnione(najmniejszy metraż/ogółem)

# %%
mieszkania_ogolem_2011_spis= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/mieszkania_ogolem_spis_2011.xlsx",sheet_name="TABLICA", header= None, skiprows=4, names=["kod","pow","liczba_mieszkan"],  dtype={"kod": str}
)

# %%
mieszkania_ogolem_2011_spis["rok"]=2011
mieszkania_ogolem_2011_spis
# Out:
#          kod                    pow  liczba_mieszkan   rok
# 0    0201000   Powiat bolesławiecki            28895  2011
# 1    0202000  Powiat dzierżoniowski            37536  2011
# 2    0203000       Powiat głogowski            30106  2011
# 3    0204000        Powiat górowski            11068  2011
# 4    0205000        Powiat jaworski            16994  2011
# ..       ...                    ...              ...   ...
# 374  3217000         Powiat wałecki            17656  2011
# 375  3218000         Powiat łobeski            12195  2011
# 376  3261000     Powiat m. Koszalin            42265  2011
# 377  3262000     Powiat m. Szczecin           160543  2011
# 378  3263000  Powiat m. Świnoujście            16390  2011
#
# [379 rows x 4 columns]

# %%
mieszkania_najmniejsze_2011_spis= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/mieszkania_najmnijesze_spis_2011.xlsx",sheet_name="TABLICA", header= None, skiprows=4, names=["kod","pow","liczba_mieszkan"],  dtype={"kod": str}
)

# %%
mieszkania_najmniejsze_2011_spis["rok"]=2011
mieszkania_najmniejsze_2011_spis
# Out:
#          kod                    pow  liczba_mieszkan   rok
# 0    0201000   Powiat bolesławiecki              489  2011
# 1    0202000  Powiat dzierżoniowski              806  2011
# 2    0203000       Powiat głogowski              405  2011
# 3    0204000        Powiat górowski              201  2011
# 4    0205000        Powiat jaworski              263  2011
# ..       ...                    ...              ...   ...
# 374  3217000         Powiat wałecki              323  2011
# 375  3218000         Powiat łobeski              268  2011
# 376  3261000     Powiat m. Koszalin              544  2011
# 377  3262000     Powiat m. Szczecin             1559  2011
# 378  3263000  Powiat m. Świnoujście              184  2011
#
# [379 rows x 4 columns]

# %%
mieszkania_odsetek_2011_spis = pd.merge(
    mieszkania_najmniejsze_2011_spis,
    mieszkania_ogolem_2011_spis,
    on=["kod", "rok", "pow"],
    suffixes=["_najmniejsze","_ogolem"]
)

# %%
mieszkania_odsetek_2011_spis["odsetek_najmiejszych_mieszkan"] = (
    mieszkania_odsetek_2011_spis["liczba_mieszkan_najmniejsze"] / mieszkania_odsetek_2011_spis["liczba_mieszkan_ogolem"]
).round(4)

# %%
mieszkania_odsetek_2011_spis=mieszkania_odsetek_2011_spis.drop(columns=["liczba_mieszkan_najmniejsze","liczba_mieszkan_ogolem"])

# %%
mieszkania_odsetek_2014 = mieszkania_odsetek_2011_spis.copy()
mieszkania_odsetek_2014["rok"] = 2014

mieszkania_odsetek_2015 = mieszkania_odsetek_2011_spis.copy()
mieszkania_odsetek_2015["rok"] = 2015

mieszkania_odsetek_2016 = mieszkania_odsetek_2011_spis.copy()
mieszkania_odsetek_2016["rok"] = 2016

mieszkania_odsetek_2017 = mieszkania_odsetek_2011_spis.copy()
mieszkania_odsetek_2017["rok"] = 2017

mieszkania_odsetek_2018 = mieszkania_odsetek_2011_spis.copy()
mieszkania_odsetek_2018["rok"] = 2018

mieszkania_odsetek_2019 = mieszkania_odsetek_2011_spis.copy()
mieszkania_odsetek_2019["rok"] = 2019

# %%
mieszkania_odsetek_full = polacz(mieszkania_odsetek_2019,
mieszkania_odsetek_2018,mieszkania_odsetek_2017,
mieszkania_odsetek_2016,mieszkania_odsetek_2015,mieszkania_odsetek_2014

)

# %%
mieszkania_ogolem_2021_spis= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/mieszkania_ogolem_spis_2021.xlsx",sheet_name="TABLICA", header= None, skiprows=4, names=["kod","pow","liczba_mieszkan"],  dtype={"kod": str}
)

# %%
mieszkania_ogolem_2021_spis["rok"]=2021
mieszkania_ogolem_2021_spis
# Out:
#          kod                    pow  liczba_mieszkan   rok
# 0    0201000   Powiat bolesławiecki            31017  2021
# 1    0202000  Powiat dzierżoniowski            36963  2021
# 2    0203000       Powiat głogowski            31969  2021
# 3    0204000        Powiat górowski            11034  2021
# 4    0205000        Powiat jaworski            16636  2021
# ..       ...                    ...              ...   ...
# 375  3217000         Powiat wałecki            17854  2021
# 376  3218000         Powiat łobeski            11848  2021
# 377  3261000     Powiat m. Koszalin            42832  2021
# 378  3262000     Powiat m. Szczecin           172149  2021
# 379  3263000  Powiat m. Świnoujście            17517  2021
#
# [380 rows x 4 columns]

# %%
mieszkania_najmniejsze_2021_spis= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/mieszkania_najmnijesze_spis_2021.xlsx",sheet_name="TABLICA", header= None, skiprows=4, names=["kod","pow","liczba_mieszkan"],  dtype={"kod": str}
)

# %%
mieszkania_najmniejsze_2021_spis["rok"]=2021
mieszkania_najmniejsze_2021_spis
# Out:
#          kod                    pow  liczba_mieszkan   rok
# 0    0201000   Powiat bolesławiecki             2702  2021
# 1    0202000  Powiat dzierżoniowski             3165  2021
# 2    0203000       Powiat głogowski             2005  2021
# 3    0204000        Powiat górowski              763  2021
# 4    0205000        Powiat jaworski             1781  2021
# ..       ...                    ...              ...   ...
# 375  3217000         Powiat wałecki             1320  2021
# 376  3218000         Powiat łobeski              696  2021
# 377  3261000     Powiat m. Koszalin             1840  2021
# 378  3262000     Powiat m. Szczecin            17611  2021
# 379  3263000  Powiat m. Świnoujście             1822  2021
#
# [380 rows x 4 columns]

# %%
mieszkania_odsetek_2021_spis = pd.merge(
    mieszkania_najmniejsze_2021_spis,
    mieszkania_ogolem_2021_spis,
    on=["kod", "rok", "pow"],
    suffixes=["_najmniejsze","_ogolem"]
)

# %%
mieszkania_odsetek_2021_spis["odsetek_najmiejszych_mieszkan"] = (
    mieszkania_odsetek_2021_spis["liczba_mieszkan_najmniejsze"] / mieszkania_odsetek_2021_spis["liczba_mieszkan_ogolem"]
).round(4)

# %%
mieszkania_odsetek_2021_spis=mieszkania_odsetek_2021_spis.drop(columns=["liczba_mieszkan_najmniejsze","liczba_mieszkan_ogolem"])

# %%
mieszkania_odsetek_2020 = mieszkania_odsetek_2021_spis.copy()
mieszkania_odsetek_2020["rok"] = 2020

mieszkania_odsetek_2021 = mieszkania_odsetek_2021_spis.copy()


mieszkania_odsetek_2022 = mieszkania_odsetek_2021_spis.copy()
mieszkania_odsetek_2022["rok"] = 2022

mieszkania_odsetek_2023 = mieszkania_odsetek_2021_spis.copy()
mieszkania_odsetek_2023["rok"] = 2023

# %%
mieszkania_odsetek_full = polacz(mieszkania_odsetek_2023,mieszkania_odsetek_2022,
mieszkania_odsetek_2021,mieszkania_odsetek_2020,
mieszkania_odsetek_full
)

# %%
mieszkania_odsetek_full
# Out:
#           kod                    pow   rok  odsetek_najmiejszych_mieszkan
# 0     0201000   Powiat bolesławiecki  2023                         0.0871
# 1     0202000  Powiat dzierżoniowski  2023                         0.0856
# 2     0203000       Powiat głogowski  2023                         0.0627
# 3     0204000        Powiat górowski  2023                         0.0691
# 4     0205000        Powiat jaworski  2023                         0.1071
# ...       ...                    ...   ...                            ...
# 3789  3217000         Powiat wałecki  2014                         0.0183
# 3790  3218000         Powiat łobeski  2014                         0.0220
# 3791  3261000     Powiat m. Koszalin  2014                         0.0129
# 3792  3262000     Powiat m. Szczecin  2014                         0.0097
# 3793  3263000  Powiat m. Świnoujście  2014                         0.0112
#
# [3794 rows x 4 columns]

# %% [markdown]
# ## osoby niepełnosprawne

# %%
osoby_niepelnosprawne_2011_spis= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/osoby_niepelnosprawne_2011_spis.xlsx",sheet_name="TABLICA", header= None, skiprows=5, names=["kod","pow","liczba_osob"],  dtype={"kod": str}
)

# %%
osoby_niepelnosprawne_2011_spis["rok"]=2011
osoby_niepelnosprawne_2011_spis
# Out:
#          kod                    pow  liczba_osob   rok
# 0    0201000   Powiat bolesławiecki        12373  2011
# 1    0202000  Powiat dzierżoniowski        15572  2011
# 2    0203000       Powiat głogowski        10389  2011
# 3    0204000        Powiat górowski         6253  2011
# 4    0205000        Powiat jaworski         5707  2011
# ..       ...                    ...          ...   ...
# 374  3217000         Powiat wałecki         8677  2011
# 375  3218000         Powiat łobeski         4929  2011
# 376  3261000     Powiat m. Koszalin        13580  2011
# 377  3262000     Powiat m. Szczecin        51043  2011
# 378  3263000  Powiat m. Świnoujście         4341  2011
#
# [379 rows x 4 columns]

# %%
osoby_niepelnosprawne_2021_spis= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/osoby_niepelnosprawne_2021_spis.xlsx",sheet_name="TABLICA", header= None, skiprows=5, names=["kod","pow","liczba_osob"],  dtype={"kod": str}
)

# %%
osoby_niepelnosprawne_2021_spis["rok"]=2021
osoby_niepelnosprawne_2021_spis
# Out:
#          kod                    pow  liczba_osob   rok
# 0    0202000  Powiat dzierżoniowski        16202  2021
# 1    0203000       Powiat głogowski        11411  2021
# 2    0204000        Powiat górowski         6575  2021
# 3    0205000        Powiat jaworski         7091  2021
# 4    0206000      Powiat karkonoski         9779  2021
# ..       ...                    ...          ...   ...
# 374  3217000         Powiat wałecki         7603  2021
# 375  3218000         Powiat łobeski         4647  2021
# 376  3261000     Powiat m. Koszalin        13990  2021
# 377  3262000     Powiat m. Szczecin        51851  2021
# 378  3263000  Powiat m. Świnoujście         4903  2021
#
# [379 rows x 4 columns]

# %%
osoby_niepelnosprawne_2014 = osoby_niepelnosprawne_2011_spis.copy()
osoby_niepelnosprawne_2014["rok"] = 2014

osoby_niepelnosprawne_2015 = osoby_niepelnosprawne_2011_spis.copy()
osoby_niepelnosprawne_2015["rok"] = 2015

osoby_niepelnosprawne_2016 = osoby_niepelnosprawne_2011_spis.copy()
osoby_niepelnosprawne_2016["rok"] = 2016

osoby_niepelnosprawne_2017 = osoby_niepelnosprawne_2011_spis.copy()
osoby_niepelnosprawne_2017["rok"] = 2017

osoby_niepelnosprawne_2018 = osoby_niepelnosprawne_2011_spis.copy()
osoby_niepelnosprawne_2018["rok"] = 2018

osoby_niepelnosprawne_2019 = osoby_niepelnosprawne_2011_spis.copy()
osoby_niepelnosprawne_2019["rok"] = 2019

# %%
osoby_niepelnosprawne_full = polacz(osoby_niepelnosprawne_2019,
osoby_niepelnosprawne_2018,osoby_niepelnosprawne_2017,
osoby_niepelnosprawne_2016,osoby_niepelnosprawne_2015,osoby_niepelnosprawne_2014

)

# %%
osoby_niepelnosprawne_2020 = osoby_niepelnosprawne_2021_spis.copy()
osoby_niepelnosprawne_2020["rok"] = 2020

osoby_niepelnosprawne_2021 = osoby_niepelnosprawne_2021_spis.copy()


osoby_niepelnosprawne_2022 = osoby_niepelnosprawne_2021_spis.copy()
osoby_niepelnosprawne_2022["rok"] = 2022

osoby_niepelnosprawne_2023 = osoby_niepelnosprawne_2021_spis.copy()
osoby_niepelnosprawne_2023["rok"] = 2023

# %%
osoby_niepelnosprawne_full = polacz(osoby_niepelnosprawne_2023,osoby_niepelnosprawne_2022,
osoby_niepelnosprawne_2021,osoby_niepelnosprawne_2020,
osoby_niepelnosprawne_full
)

# %%
osoby_niepelnosprawne_full
# Out:
#           kod                    pow  liczba_osob   rok
# 0     0202000  Powiat dzierżoniowski        16202  2023
# 1     0203000       Powiat głogowski        11411  2023
# 2     0204000        Powiat górowski         6575  2023
# 3     0205000        Powiat jaworski         7091  2023
# 4     0206000      Powiat karkonoski         9779  2023
# ...       ...                    ...          ...   ...
# 3785  3217000         Powiat wałecki         8677  2014
# 3786  3218000         Powiat łobeski         4929  2014
# 3787  3261000     Powiat m. Koszalin        13580  2014
# 3788  3262000     Powiat m. Szczecin        51043  2014
# 3789  3263000  Powiat m. Świnoujście         4341  2014
#
# [3790 rows x 4 columns]

# %% [markdown]
# # Dane korelujace- merged

# %%
dane_korelujace=bezrobocie_odsetek
dane_korelujace= pd.merge(dane_korelujace, wynagrodzenie_full, on=["rok","kod","pow"], how="outer")
dane_korelujace= pd.merge(dane_korelujace, rozwody_odsetek, on=["rok","kod","pow"], how="outer")
dane_korelujace= pd.merge(dane_korelujace, osoby_na_1_izbe_full, on=["rok","kod","pow"], how="outer")
dane_korelujace= pd.merge(dane_korelujace, powierzchnia_na_1_osobe_full, on=["rok","kod","pow"], how="outer")
dane_korelujace
# Out:
#           kod                    pow   rok  \
# 0     0201000   Powiat bolesławiecki  2014
# 1     0202000  Powiat dzierżoniowski  2014
# 2     0203000       Powiat głogowski  2014
# 3     0204000        Powiat górowski  2014
# 4     0205000        Powiat jaworski  2014
# ...       ...                    ...   ...
# 3795  3217000         Powiat wałecki  2023
# 3796  3218000         Powiat łobeski  2023
# 3797  3261000     Powiat m. Koszalin  2023
# 3798  3262000     Powiat m. Szczecin  2023
# 3799  3263000  Powiat m. Świnoujście  2023
#
#       odsetek_bezrobotnych_dlugotrwalych  wielkosc_wynagrodzenia  \
# 0                                 0.4637                    3422
# 1                                 0.4751                    3299
# 2                                 0.5690                    3460
# 3                                 0.6394                    3142
# 4                                 0.5921                    3142
# ...                                  ...                     ...
# 3795                              0.4854                    6651
# 3796                              0.5389                    6257
# 3797                              0.4891                    6828
# 3798                              0.3982                    7933
# 3799                              0.3835                    6847
#
#       odsetek_rozwodow  liczba_osob_na_1_izbe  \
# 0               0.3787                   0.72
# 1               0.4310                   0.76
# 2               0.4189                   0.75
# 3               0.3918                   0.77
# 4               0.3508                   0.75
# ...                ...                    ...
# 3795            0.3410                   0.66
# 3796            0.4160                   0.67
# 3797            0.4439                   0.60
# 3798            0.3940                   0.59
# 3799            0.3718                   0.52
#
#       przecietna_powierzchnia_mieszkania_na_1_osobe
# 0                                              26.5
# 1                                              24.0
# 2                                              23.2
# 3                                              25.0
# 4                                              25.2
# ...                                             ...
# 3795                                           28.6
# 3796                                           27.5
# 3797                                           30.6
# 3798                                           30.9
# 3799                                           35.0
#
# [3800 rows x 8 columns]

# %%
dane_korelujace.to_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/dane_korelujace.xlsx", sheet_name= "dane_korelujace" ,index=False)

# %%
dane_korelujace_spis=mieszkania_odsetek_full
dane_korelujace_spis= pd.merge(dane_korelujace_spis, osoby_niepelnosprawne_full, on=["rok","kod","pow"], how="outer")
dane_korelujace_spis
# Out:
#           kod                    pow   rok  odsetek_najmiejszych_mieszkan  \
# 0     0201000   Powiat bolesławiecki  2014                         0.0169
# 1     0202000  Powiat dzierżoniowski  2014                         0.0215
# 2     0203000       Powiat głogowski  2014                         0.0135
# 3     0204000        Powiat górowski  2014                         0.0182
# 4     0205000        Powiat jaworski  2014                         0.0155
# ...       ...                    ...   ...                            ...
# 3789  3217000         Powiat wałecki  2023                         0.0739
# 3790  3218000         Powiat łobeski  2023                         0.0587
# 3791  3261000     Powiat m. Koszalin  2023                         0.0430
# 3792  3262000     Powiat m. Szczecin  2023                         0.1023
# 3793  3263000  Powiat m. Świnoujście  2023                         0.1040
#
#       liczba_osob
# 0         12373.0
# 1         15572.0
# 2         10389.0
# 3          6253.0
# 4          5707.0
# ...           ...
# 3789       7603.0
# 3790       4647.0
# 3791      13990.0
# 3792      51851.0
# 3793       4903.0
#
# [3794 rows x 5 columns]

# %%
dane_korelujace_spis.to_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/dane_korelujace_spis.xlsx", sheet_name= "dane_korelujaces_spis" ,index=False)

# %%
with pd.ExcelWriter('dane_korelujace.xlsx') as writer:
 dane_korelujace.to_excel(writer, index=False, sheet_name='dane_korelujace')

# %%
with pd.ExcelWriter('dane_korelujace_spis.xlsx') as writer:
 dane_korelujace_spis.to_excel(writer, index=False, sheet_name='dane_korelujace_spis')
