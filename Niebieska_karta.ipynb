# %% [markdown]
# <a href="https://colab.research.google.com/github/Francho03/Praca-licencjacka/blob/main/Niebieska_karta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# !pip install xlsxwriter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 4.6 MB/s eta 0:00:00
# ...

# %%
nb=pd.read_excel("/content/Sprawozdanie przemoc_2021.xlsx", sheet_name="Część 10")
nb
# Out:
#      Unnamed: 0          Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0           NaN                 NaN        NaN        NaN              NaN
# 1           NaN                 NaN        NaN        NaN              NaN
# 2           NaN                 NaN        NaN        NaN              NaN
# 3           NaN                 NaN        NaN        NaN              NaN
# 4           NaN                 NaN        NaN        NaN              NaN
# ...         ...                 ...        ...        ...              ...
# 2525       2512  zachodniopomorskie    wałecki     Tuczno  miejsko-wiejska
# 2526       2513  zachodniopomorskie    wałecki      Wałcz          miejska
# 2527       2514  zachodniopomorskie    wałecki      Wałcz          wiejska
# 2528       2515                   -          -          -                -
# 2529          X               RAZEM          X          -                -
#
# ...

# %%
nb.drop(nb.index[0:14],axis=0,inplace=True)
nb
# Out:
#      Unnamed: 0          Unnamed: 1     Unnamed: 2   Unnamed: 3  \
# 14            1                   -              -            -
# 15            2                   -              -            -
# 16            3                   -              -            -
# 17            4        dolnośląskie              -            -
# 18            5        dolnośląskie  bolesławiecki  Bolesławiec
# ...         ...                 ...            ...          ...
# 2525       2512  zachodniopomorskie        wałecki       Tuczno
# 2526       2513  zachodniopomorskie        wałecki        Wałcz
# 2527       2514  zachodniopomorskie        wałecki        Wałcz
# 2528       2515                   -              -            -
# 2529          X               RAZEM              X            -
#
#            Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 14                  -      MKiDN  040000000000         33          X
# ...

# %%
# def PodzialDanych (nb, start_col, end_col, columns_names):
#     """
#    funkcja pomagająca podzielić dane- prototyp nie użyta na razie

#     parametry:
#     nb (DataFrame)- zbiór danych
#     start_col (int): indeks kolumn poczatkowej
#     end_col (int): indeks kolumn koncowej
#     columns_names (list): list nazw kolumn

#     Returns:
#     DataFrame: oczyszczony i nazwany zbior danych
#     """
#     # Wyrzuca kolumny
#     df = nb.drop(nb.iloc[:, start_col:end_col], axis=1)
#     df = df.drop(df.iloc[:, 13:], axis=1)
#     df.columns = columns_names  # zmnnienia nazwy kolumn
#     return df

# # podzielone dane-"liczba wszczętych procedur"
# nb_sporzadzone_formularze1 = extract_data(nb, 13, 127, ["LP.", "wojewodztwo", "powiat", "gmina", "typ gminy", "typ\njednostki", "KESO", "razem", "MRiPS", "MSWIA", "MZ", "MEiN", "MKDNiS"])

# # podzielone dane-"liczba kontynuowanych procedur"
# nb_kontynuowane_formularze2 = extract_data(nb, 7, 13, ["LP.", "wojewodztwo", "powiat", "gmina", "typ gminy", "typ\njednostki", "KESO", "razem", "MRiPS", "MSWIA", "MZ", "MEiN", "MKDNiS"])

# %%
#liczba wszczętych w danym roku procedur "Niebieska Karta", tj. liczba sporządzonych formularzy "Niebieska Karta-A" przez przedstawicieli poszczególnych podmiotów wszczynających procedurę
nb_sporzadzone_formularze1=nb.drop(nb.iloc[:,13:127],axis=1)
nb_sporzadzone_formularze1.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]

print(nb_sporzadzone_formularze1.isnull().sum())  # sprawdzanie danych
print(nb_sporzadzone_formularze1.describe())
nb_sporzadzone_formularze1
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    189    187     2     2     2      2
# top     040000000000      0      0     X     X     X      X
# freq               1    200    200  2514  2514  2514   2514
# ...

# %%
#liczba kontynuowanych w danym roku procedur "Niebieska Karta" wszczętych w latach poprzedzających rok sprawozdawczy
dane=nb.drop(nb.iloc[:,7:13],axis=1)
nb_kontynuowane_formularze2=dane.drop(dane.iloc[:,13:127],axis=1)
nb_kontynuowane_formularze2.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS]"]

print(nb_kontynuowane_formularze2.isnull().sum())  # sprawdzanie danych
print(nb_kontynuowane_formularze2.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS]           0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS]
# count           2516   2516   2516  2516  2516  2516    2516
# unique          2516    147    147     1     1     1       1
# top     040000000000      0      0     X     X     X       X
# freq               1    209    209  2516  2516  2516    2516

# %%
#liczba wypełnionych formularzy "Niebieska Karta-A" dokumentujących kolejne zdarzenie stosowania przemocy w sprawach toczących się procedur "Niebieska Karta"
dane1=nb.drop(nb.iloc[:,7:19],axis=1)
nb_wypelnione_formularze3=dane1.drop(dane.iloc[:,19:127],axis=1)
nb_wypelnione_formularze3.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]

print(nb_wypelnione_formularze3.isnull().sum())  # sprawdzanie danych
print(nb_wypelnione_formularze3.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516     96     96     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    801    801  2516  2516  2516   2516

# %%
#liczba rodzin objętych w danym roku działaniami w ramach procedury "Niebieska Karta" -ogółem

dane2=nb.drop(nb.iloc[:,7:25],axis=1)
nb_rodzin_ogolem4=dane2.drop(dane2.iloc[:,13:127],axis=1)
nb_rodzin_ogolem4.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]


print(nb_rodzin_ogolem4.isnull().sum())  # sprawdzanie danych
print(nb_rodzin_ogolem4.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    241    241     1     1     1      1
# top     040000000000     10     10     X     X     X      X
# freq               1     97     97  2516  2516  2516   2516

# %%
#liczba rodzin objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-w tym ze względu na problem przemocy psychicznej
dane3=nb.drop(nb.iloc[:,7:31],axis=1)
nb_rodzin_przemoc_psychiczna5=dane3.drop(dane3.iloc[:,13:127],axis=1)
nb_rodzin_przemoc_psychiczna5.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]

print(nb_rodzin_przemoc_psychiczna5.isnull().sum())  # sprawdzanie danych
print(nb_rodzin_przemoc_psychiczna5.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    219    219     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    144    144  2516  2516  2516   2516

# %%
#liczba rodzin objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-w tym ze względu na problem przemocy fizycznej
dane4=nb.drop(nb.iloc[:,7:37],axis=1)
nb_rodzin_przemoc_fizyczna6=dane4.drop(dane4.iloc[:,13:127],axis=1)
nb_rodzin_przemoc_fizyczna6.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]


print(nb_rodzin_przemoc_fizyczna6.isnull().sum())  # sprawdzanie danych
print(nb_rodzin_przemoc_fizyczna6.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    193    193     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    138    138  2516  2516  2516   2516

# %%
#liczba rodzin objętych w danym roku działaniami w ramach procedury "Niebieska Karta"- w tym ze względu na problem przemocy seksualnej
dane5=nb.drop(nb.iloc[:,7:43],axis=1)
nb_rodzin_przemoc_seksualna7=dane5.drop(dane5.iloc[:,13:127],axis=1)
nb_rodzin_przemoc_seksualna7.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]

print(nb_rodzin_przemoc_seksualna7.isnull().sum())  # sprawdzanie danych
print(nb_rodzin_przemoc_seksualna7.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516     45     45     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1   1800   1800  2516  2516  2516   2516

# %%
#liczba osób w rodzinach objętych w danym roku działaniami w ramach procedury "Niebieska Karta"
dane6=nb.drop(nb.iloc[:,7:49],axis=1)
nb_osob8=dane6.drop(dane6.iloc[:,13:127],axis=1)
nb_osob8.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]


print(nb_osob8.isnull().sum())  # sprawdzanie danych
print(nb_osob8.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    405    405     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    188    188  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-ogółem
dane7=nb.drop(nb.iloc[:,7:55],axis=1)
nb_ogolem9=dane7.drop(dane7.iloc[:,13:127],axis=1)
nb_ogolem9.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]

print(nb_ogolem9.isnull().sum())  # sprawdzanie danych
print(nb_ogolem9.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    307    307     1     1     1      1
# top     040000000000     14     14     X     X     X      X
# freq               1     58     58  2516  2516  2516   2516

# %%
# liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"- kobiety ogółem
dane8=nb.drop(nb.iloc[:,7:61],axis=1)
nb_kobiety_ogolem10=dane8.drop(dane8.iloc[:,13:127],axis=1)
nb_kobiety_ogolem10.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]



print(nb_kobiety_ogolem10.isnull().sum())  # sprawdzanie danych
print(nb_kobiety_ogolem10.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    213    213     1     1     1      1
# top     040000000000     10     10     X     X     X      X
# freq               1    115    115  2516  2516  2516   2516

# %%
# liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"- kobiety w tym niepełnosprawne
dane9=nb.drop(nb.iloc[:,7:67],axis=1)
nb_kobiety_niepelnosprawne11=dane9.drop(dane9.iloc[:,13:127],axis=1)
nb_kobiety_niepelnosprawne11.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]


print(nb_kobiety_niepelnosprawne11.isnull().sum())  # sprawdzanie danych
print(nb_kobiety_niepelnosprawne11.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516     58     58     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1   1326   1326  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"- kobiety w tym starsze
dane10=nb.drop(nb.iloc[:,7:73],axis=1)
nb_kobiety_starsze12=dane10.drop(dane10.iloc[:,13:127],axis=1)
nb_kobiety_starsze12.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]



print(nb_kobiety_starsze12.isnull().sum())  # sprawdzanie danych
print(nb_kobiety_starsze12.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516     90     90     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    501    501  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-mężczyźni ogółem
dane11=nb.drop(nb.iloc[:,7:79],axis=1)
nb_mezczyzni_ogolem13=dane11.drop(dane11.iloc[:,13:127],axis=1)
nb_mezczyzni_ogolem13.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]


print(nb_mezczyzni_ogolem13.isnull().sum())  # sprawdzanie danych
print(nb_mezczyzni_ogolem13.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    120    120     1     1     1      1
# top     040000000000      1      1     X     X     X      X
# freq               1    383    383  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-mężczyźni w tym niepełnosprawni
dane12=nb.drop(nb.iloc[:,7:85],axis=1)
nb_mezczyzni_niepelnosprawni14=dane12.drop(dane12.iloc[:,13:127],axis=1)
nb_mezczyzni_niepelnosprawni14.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]


print(nb_mezczyzni_niepelnosprawni14.isnull().sum())  # sprawdzanie danych
print(nb_mezczyzni_niepelnosprawni14.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516     43     43     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1   1721   1721  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-mężczyźni w tym starsi
dane13=nb.drop(nb.iloc[:,7:91],axis=1)
nb_mezczyzni_starsi15=dane13.drop(dane13.iloc[:,13:127],axis=1)
nb_mezczyzni_starsi15.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]



print(nb_mezczyzni_starsi15.isnull().sum())  # sprawdzanie danych
print(nb_mezczyzni_starsi15.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516     51     51     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1   1200   1200  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-dzieci ogółem
dane14=nb.drop(nb.iloc[:,7:97],axis=1)
nb_dzieci_ogolem16=dane14.drop(dane14.iloc[:,13:127],axis=1)
nb_dzieci_ogolem16.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]
nb_dzieci_ogolem16


print(nb_dzieci_ogolem16.isnull().sum())  # sprawdzanie danych
print(nb_dzieci_ogolem16.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    179    179     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    395    395  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-dzieci w tym dziewczynki
dane15=nb.drop(nb.iloc[:,7:103],axis=1)
nb_dzieci_dziewczynki17=dane15.drop(dane15.iloc[:,13:127],axis=1)
nb_dzieci_dziewczynki17.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]



print(nb_dzieci_dziewczynki17.isnull().sum())  # sprawdzanie danych
print(nb_dzieci_dziewczynki17.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    129    129     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    624    624  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-dzieci w tym chłopcy
dane16=nb.drop(nb.iloc[:,7:109],axis=1)
nb_dzieci_chlopcy18=dane16.drop(dane16.iloc[:,13:127],axis=1)
nb_dzieci_chlopcy18.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]


print(nb_dzieci_chlopcy18.isnull().sum())  # sprawdzanie danych
print(nb_dzieci_chlopcy18.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    126    126     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    608    608  2516  2516  2516   2516

# %%
#liczba osób doświadczających przemocy w rodzinie, objętych w danym roku działaniami w ramach procedury "Niebieska Karta"-dzieci w tym niepełnosprawne
dane17=nb.drop(nb.iloc[:,7:115],axis=1)
nb_dzieci_niepelnosprawne19=dane17.drop(dane17.iloc[:,13:127],axis=1)
nb_dzieci_niepelnosprawne19.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]


print(nb_dzieci_niepelnosprawne19.isnull().sum())  # sprawdzanie danych
print(nb_dzieci_niepelnosprawne19.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516     41     41     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1   1873   1873  2516  2516  2516   2516

# %%
#liczba wypełnionych formularzy "Niebieska Karta-C"
nb_C_20=nb.drop(nb.iloc[:,7:121],axis=1)
nb_C_20.columns=  ["LP.", "wojewodztwo", "powiat","gmina", "typ gminy", "typ\njednostki","KESO","razem",	"MRiPS"	,"MSWIA",	"MZ",	"MEiN",	"MKDNiS"]
nb_C_20


print(nb_C_20.isnull().sum())  # sprawdzanie danych
print(nb_C_20.describe())
# Out:
# LP.               0
# wojewodztwo       0
# powiat            0
# gmina             0
# typ gminy         0
# typ\njednostki    0
# KESO              0
# razem             0
# MRiPS             0
# MSWIA             0
# MZ                0
# MEiN              0
# MKDNiS            0
# dtype: int64
#          LP.  wojewodztwo       powiat gmina typ gminy typ\njednostki  \
# count   2516         2516         2516  2516      2516           2516
# unique  2516           18          372  2268         5              8
# top        1  mazowieckie  tomaszowski     -   wiejska            OPS
# freq       1          333           24    21      1546           2429
#
#                 KESO  razem  MRiPS MSWIA    MZ  MEiN MKDNiS
# count           2516   2516   2516  2516  2516  2516   2516
# unique          2516    180    180     1     1     1      1
# top     040000000000      0      0     X     X     X      X
# freq               1    170    170  2516  2516  2516   2516

# %%
# exportowanie danych
dfs_to_export = {
    'sporzadzone_formularze1.csv': nb_sporzadzone_formularze1,
    'kontynuowane_formularze2.csv': nb_kontynuowane_formularze2,
    'wypelnione_formularze3.csv': nb_wypelnione_formularze3,
    'rodzin_ogolem4.csv': nb_rodzin_ogolem4,
    'rodzin_przemoc_psychiczna5.csv': nb_rodzin_przemoc_psychiczna5,
    'rodzin_przemoc_fizyczna6.csv': nb_rodzin_przemoc_fizyczna6,
    'rodzin_przemoc_seksualna7.csv': nb_rodzin_przemoc_seksualna7,
    'osob8.csv': nb_osob8,
    'ogolem9.csv': nb_ogolem9,
    'kobiety_ogolem10.csv': nb_kobiety_ogolem10,
    'kobiety_niepelnosprawne11.csv': nb_kobiety_niepelnosprawne11,
    'kobiety_starsze12.csv': nb_kobiety_starsze12,
    'mezczyzni_ogolem13.csv': nb_mezczyzni_ogolem13,
    'mezczyzni_niepelnosprawni14.csv': nb_mezczyzni_niepelnosprawni14,
    'mezczyzni_starsi15.csv': nb_mezczyzni_starsi15,
    'dzieci_ogolem16.csv': nb_dzieci_ogolem16,
    'dzieci_dziewczynki17.csv': nb_dzieci_dziewczynki17,
    'dzieci_chlopcy18.csv': nb_dzieci_chlopcy18,
    'dzieci_niepelnosprawne19.csv': nb_dzieci_niepelnosprawne19,
    'nb_C_20.csv': nb_C_20
}


for filename, df in dfs_to_export.items():
    df.to_csv(filename, index=False)
    print(f"Exported {filename}")
# Out:
# Exported sporzadzone_formularze1.csv
# Exported kontynuowane_formularze2.csv
# Exported wypelnione_formularze3.csv
# Exported rodzin_ogolem4.csv
# Exported rodzin_przemoc_psychiczna5.csv
# Exported rodzin_przemoc_fizyczna6.csv
# Exported rodzin_przemoc_seksualna7.csv
# Exported osob8.csv
# Exported ogolem9.csv
# Exported kobiety_ogolem10.csv
# Exported kobiety_niepelnosprawne11.csv
# Exported kobiety_starsze12.csv
# Exported mezczyzni_ogolem13.csv
# Exported mezczyzni_niepelnosprawni14.csv
# Exported mezczyzni_starsi15.csv
# Exported dzieci_ogolem16.csv
# Exported dzieci_dziewczynki17.csv
# Exported dzieci_chlopcy18.csv
# Exported dzieci_niepelnosprawne19.csv
# Exported nb_C_20.csv

# %%
output_excel_file = 'Podzielonedaneexcel.xlsx'

with pd.ExcelWriter(output_excel_file, engine='xlsxwriter') as writer:

    nb_sporzadzone_formularze1.to_excel(writer, sheet_name='sporzadzone_formularze1', index=False)
    nb_kontynuowane_formularze2.to_excel(writer, sheet_name='kontynuowane_formularze2', index=False)
    nb_wypelnione_formularze3.to_excel(writer, sheet_name='wypelnione_formularze3', index=False)
    nb_rodzin_ogolem4.to_excel(writer, sheet_name='rodzin_ogolem4', index=False)
    nb_rodzin_przemoc_psychiczna5.to_excel(writer, sheet_name='rodzin_przemoc_psychiczna5', index=False)
    nb_rodzin_przemoc_fizyczna6.to_excel(writer, sheet_name='rodzin_przemoc_fizyczna6', index=False)
    nb_rodzin_przemoc_seksualna7.to_excel(writer, sheet_name='rodzin_przemoc_seksualna7', index=False)
    nb_osob8.to_excel(writer, sheet_name='osob8', index=False)
    nb_ogolem9.to_excel(writer, sheet_name='ogolem9', index=False)
    nb_kobiety_ogolem10.to_excel(writer, sheet_name='kobiety_ogolem10', index=False)
    nb_kobiety_niepelnosprawne11.to_excel(writer, sheet_name='kobiety_niepelnosprawne11', index=False)
    nb_kobiety_starsze12.to_excel(writer, sheet_name='kobiety_starsze12', index=False)
    nb_mezczyzni_ogolem13.to_excel(writer, sheet_name='mezczyzni_ogolem13', index=False)
    nb_mezczyzni_niepelnosprawni14.to_excel(writer, sheet_name='mezczyzni_niepelnosprawni14', index=False)
    nb_mezczyzni_starsi15.to_excel(writer, sheet_name='mezczyzni_starsi15', index=False)
    nb_dzieci_ogolem16.to_excel(writer, sheet_name='dzieci_ogolem16', index=False)
    nb_dzieci_dziewczynki17.to_excel(writer, sheet_name='dzieci_dziewczynki17', index=False)
    nb_dzieci_chlopcy18.to_excel(writer, sheet_name='dzieci_chlopcy18', index=False)
    nb_dzieci_niepelnosprawne19.to_excel(writer, sheet_name='dzieci_niepelnosprawne19', index=False)
    nb_C_20.to_excel(writer, sheet_name='nb_C_20', index=False)

print(f"DataFrames exported to {output_excel_file}")
# Out:
# DataFrames exported to Podzielonedaneexcel.xlsx

# %%
merge_columns = ['LP.', 'wojewodztwo', 'powiat', 'gmina', 'typ gminy', 'typ\njednostki', 'KESO']

merged_data = nb_sporzadzone_formularze1

merged_data = pd.merge(merged_data, nb_kontynuowane_formularze2, on=merge_columns, how='outer', suffixes=('', '_kontynuowane'))
merged_data = pd.merge(merged_data, nb_wypelnione_formularze3, on=merge_columns, how='outer', suffixes=('', '_wypelnione'))
merged_data = pd.merge(merged_data, nb_rodzin_ogolem4, on=merge_columns, how='outer', suffixes=('', '_rodzin_ogolem'))
merged_data = pd.merge(merged_data, nb_rodzin_przemoc_psychiczna5, on=merge_columns, how='outer', suffixes=('', '_rodzin_psychiczna'))
merged_data = pd.merge(merged_data, nb_rodzin_przemoc_fizyczna6, on=merge_columns, how='outer', suffixes=('', '_rodzin_fizyczna'))
merged_data = pd.merge(merged_data, nb_rodzin_przemoc_seksualna7, on=merge_columns, how='outer', suffixes=('', '_rodzin_seksualna'))
merged_data = pd.merge(merged_data, nb_osob8, on=merge_columns, how='outer', suffixes=('', '_osob'))
merged_data = pd.merge(merged_data, nb_ogolem9, on=merge_columns, how='outer', suffixes=('', '_ogolem'))
merged_data = pd.merge(merged_data, nb_kobiety_ogolem10, on=merge_columns, how='outer', suffixes=('', '_kobiety_ogolem'))
merged_data = pd.merge(merged_data, nb_kobiety_niepelnosprawne11, on=merge_columns, how='outer', suffixes=('', '_kobiety_niepelnosprawne'))
merged_data = pd.merge(merged_data, nb_kobiety_starsze12, on=merge_columns, how='outer', suffixes=('', '_kobiety_starsze'))
merged_data = pd.merge(merged_data, nb_mezczyzni_ogolem13, on=merge_columns, how='outer', suffixes=('', '_mezczyzni_ogolem'))
merged_data = pd.merge(merged_data, nb_mezczyzni_niepelnosprawni14, on=merge_columns, how='outer', suffixes=('', '_mezczyzni_niepelnosprawni'))
merged_data = pd.merge(merged_data, nb_mezczyzni_starsi15, on=merge_columns, how='outer', suffixes=('', '_mezczyzni_starsi'))
merged_data = pd.merge(merged_data, nb_dzieci_ogolem16, on=merge_columns, how='outer', suffixes=('', '_dzieci_ogolem'))
merged_data = pd.merge(merged_data, nb_dzieci_dziewczynki17, on=merge_columns, how='outer', suffixes=('', '_dzieci_dziewczynki'))
merged_data = pd.merge(merged_data, nb_dzieci_chlopcy18, on=merge_columns, how='outer', suffixes=('', '_dzieci_chlopcy'))
merged_data = pd.merge(merged_data, nb_dzieci_niepelnosprawne19, on=merge_columns, how='outer', suffixes=('', '_dzieci_niepelnosprawne'))
merged_data = pd.merge(merged_data, nb_C_20, on=merge_columns, how='outer', suffixes=('', '_formularze_C'))

merged_data.to_csv('merged_data.csv', index=False)


merged_data
# Out:
# Merged data has been exported to 'merged_data.csv'
#        LP.         wojewodztwo         powiat        gmina        typ gminy  \
# 0        1                   -              -            -                -
# 1        2                   -              -            -                -
# 2        3                   -              -            -                -
# 3        4        dolnośląskie              -            -                -
# 4        5        dolnośląskie  bolesławiecki  Bolesławiec          miejska
# ...    ...                 ...            ...          ...              ...
# 2511  2512  zachodniopomorskie        wałecki       Tuczno  miejsko-wiejska
# 2512  2513  zachodniopomorskie        wałecki        Wałcz          miejska
# 2513  2514  zachodniopomorskie        wałecki        Wałcz          wiejska
# 2514  2515                   -              -            -                -
# 2515     X               RAZEM              X            -                -
#
# ...

# %%
merge_columns = ['LP.', 'wojewodztwo', 'powiat', 'gmina', 'typ gminy', 'typ\njednostki', 'KESO']

merged_dataexcel = nb_sporzadzone_formularze1


merged_dataexcel = pd.merge(merged_dataexcel, nb_kontynuowane_formularze2, on=merge_columns, how='outer', suffixes=('', '_kontynuowane'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_wypelnione_formularze3, on=merge_columns, how='outer', suffixes=('', '_wypelnione'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_rodzin_ogolem4, on=merge_columns, how='outer', suffixes=('', '_rodzin_ogolem'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_rodzin_przemoc_psychiczna5, on=merge_columns, how='outer', suffixes=('', '_rodzin_psychiczna'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_rodzin_przemoc_fizyczna6, on=merge_columns, how='outer', suffixes=('', '_rodzin_fizyczna'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_rodzin_przemoc_seksualna7, on=merge_columns, how='outer', suffixes=('', '_rodzin_seksualna'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_osob8, on=merge_columns, how='outer', suffixes=('', '_osob'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_ogolem9, on=merge_columns, how='outer', suffixes=('', '_ogolem'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_kobiety_ogolem10, on=merge_columns, how='outer', suffixes=('', '_kobiety_ogolem'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_kobiety_niepelnosprawne11, on=merge_columns, how='outer', suffixes=('', '_kobiety_niepelnosprawne'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_kobiety_starsze12, on=merge_columns, how='outer', suffixes=('', '_kobiety_starsze'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_mezczyzni_ogolem13, on=merge_columns, how='outer', suffixes=('', '_mezczyzni_ogolem'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_mezczyzni_niepelnosprawni14, on=merge_columns, how='outer', suffixes=('', '_mezczyzni_niepelnosprawni'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_mezczyzni_starsi15, on=merge_columns, how='outer', suffixes=('', '_mezczyzni_starsi'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_dzieci_ogolem16, on=merge_columns, how='outer', suffixes=('', '_dzieci_ogolem'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_dzieci_dziewczynki17, on=merge_columns, how='outer', suffixes=('', '_dzieci_dziewczynki'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_dzieci_chlopcy18, on=merge_columns, how='outer', suffixes=('', '_dzieci_chlopcy'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_dzieci_niepelnosprawne19, on=merge_columns, how='outer', suffixes=('', '_dzieci_niepelnosprawne'))
merged_dataexcel = pd.merge(merged_dataexcel, nb_C_20, on=merge_columns, how='outer', suffixes=('', '_formularze_C'))


with pd.ExcelWriter('merged_dataexcel.xlsx') as writer:
  merged_dataexcel.to_excel(writer, index=False, sheet_name='MergedData')
merged_dataexcel
# Out:
#        LP.         wojewodztwo         powiat        gmina        typ gminy  \
# 0        1                   -              -            -                -
# 1        2                   -              -            -                -
# 2        3                   -              -            -                -
# 3        4        dolnośląskie              -            -                -
# 4        5        dolnośląskie  bolesławiecki  Bolesławiec          miejska
# ...    ...                 ...            ...          ...              ...
# 2511  2512  zachodniopomorskie        wałecki       Tuczno  miejsko-wiejska
# 2512  2513  zachodniopomorskie        wałecki        Wałcz          miejska
# 2513  2514  zachodniopomorskie        wałecki        Wałcz          wiejska
# 2514  2515                   -              -            -                -
# 2515     X               RAZEM              X            -                -
#
# ...
