# %% [markdown]
# <a href="https://colab.research.google.com/github/Francho03/Praca-licencjacka/blob/main/Niebieska_karta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from typing import Sequence
nb=pd.read_excel("/content/Sprawozdanie przemoc_2021.xlsx", sheet_name="Część 10", header= 8)
nb.head()
# Out:
#    LP. Województwo Powiat Gmina Typ gminy Typ\njednostki KESO  \
# 0  NaN         NaN    NaN   NaN       NaN            NaN  NaN
# 1  NaN         NaN    NaN   NaN       NaN            NaN  NaN
# 2  NaN         NaN    NaN   NaN       NaN            NaN  NaN
# 3  NaN         NaN    NaN   NaN       NaN            NaN  NaN
# 4  NaN         NaN    NaN   NaN       NaN            NaN  NaN
#
#   2.3.1. Realizacja procedury "Niebieska Karta" przez uprawnione podmioty  \
# 0  liczba wszczętych w danym roku procedur "Niebi...
# 1                                                NaN
# 2                                                NaN
# 3                             Podmiot odpowiedzialny
# 4                                              Razem
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 117 Unnamed: 118 Unnamed: 119  \
# 0        NaN        NaN  ...          NaN          NaN          NaN
# 1        NaN        NaN  ...          NaN          NaN          NaN
# 2        NaN        NaN  ...          NaN          NaN          NaN
# 3        NaN        NaN  ...          NaN          NaN          NaN
# 4      MRiPS      MSWIA  ...        MSWIA           MZ         MEiN
#
#   Unnamed: 120                                       Unnamed: 121  \
# 0          NaN  liczba wypełnionych formularzy "Niebieska Kart...
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                             Podmiot odpowiedzialny
# 4       MKDNiS                                              Razem
#
#   Unnamed: 122 Unnamed: 123 Unnamed: 124 Unnamed: 125 Unnamed: 126
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4        MRiPS        MSWIA           MZ         MEiN       MKDNiS
#
# [5 rows x 127 columns]
