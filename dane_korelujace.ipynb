# %% [markdown]
# <a href="https://colab.research.google.com/github/Francho03/Praca-licencjacka/blob/main/dane_korelujace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
def polacz(*datasets):


    return pd.concat(datasets, ignore_index=True)

# %%
columns_names=["kod","pow","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"]

# %%
bezrobocie= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/Bezrobotni.xlsx",sheet_name="TABLICA", header= None, skiprows=3, names=columns_names)

# %%
bezrobocie_2014 = bezrobocie.iloc[:, [0,1,2]]
bezrobocie_2014["rok"] = 2014
bezrobocie_2014 = bezrobocie_2014.iloc[:, [0,1,3,2]]
bezrobocie_2014.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2015 = bezrobocie.iloc[:, [0,1,3]]
bezrobocie_2015["rok"] = 2015
bezrobocie_2015 = bezrobocie_2015.iloc[:, [0,1,3,2]]
bezrobocie_2015.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2016 = bezrobocie.iloc[:, [0,1,4]]
bezrobocie_2016["rok"] = 2016
bezrobocie_2016 = bezrobocie_2016.iloc[:, [0,1,3,2]]
bezrobocie_2016.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2017 = bezrobocie.iloc[:, [0,1,5]]
bezrobocie_2017["rok"] = 2017
bezrobocie_2017 = bezrobocie_2017.iloc[:, [0,1,3,2]]
bezrobocie_2017.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2018 = bezrobocie.iloc[:, [0,1,6]]
bezrobocie_2018["rok"] = 2018
bezrobocie_2018 = bezrobocie_2018.iloc[:, [0,1,3,2]]
bezrobocie_2018.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2019 = bezrobocie.iloc[:, [0,1,7]]
bezrobocie_2019["rok"] = 2019
bezrobocie_2019 = bezrobocie_2019.iloc[:, [0,1,3,2]]
bezrobocie_2019.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2020 = bezrobocie.iloc[:, [0,1,8]]
bezrobocie_2020["rok"] = 2020
bezrobocie_2020 = bezrobocie_2020.iloc[:, [0,1,3,2]]
bezrobocie_2020.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2021 = bezrobocie.iloc[:, [0,1,9]]
bezrobocie_2021["rok"] = 2021
bezrobocie_2021 = bezrobocie_2021.iloc[:, [0,1,3,2]]
bezrobocie_2021.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2022 = bezrobocie.iloc[:, [0,1,10]]
bezrobocie_2022["rok"] = 2022
bezrobocie_2022 = bezrobocie_2022.iloc[:, [0,1,3,2]]
bezrobocie_2022.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]

bezrobocie_2023 = bezrobocie.iloc[:, [0,1,11]]
bezrobocie_2023["rok"] = 2023
bezrobocie_2023 = bezrobocie_2023.iloc[:, [0,1,3,2]]
bezrobocie_2023.columns = ["kod", "pow", "rok", "liczba_bezrobotnych"]
# Out:
# <ipython-input-56-fdcb04eea190>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2014["rok"] = 2014
# <ipython-input-56-fdcb04eea190>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bezrobocie_2015["rok"] = 2015
# <ipython-input-56-fdcb04eea190>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
bezrobocie_full = polacz(bezrobocie_2023
   ,bezrobocie_2022,bezrobocie_2021,
bezrobocie_2020, bezrobocie_2019,
bezrobocie_2018,bezrobocie_2017,
bezrobocie_2016,bezrobocie_2015,bezrobocie_2014

)

# %%
bezrobocie_full["liczba_bezrobotnych"]=bezrobocie_full["liczba_bezrobotnych"].astype(int)
bezrobocie_full["kod"]=bezrobocie_full['kod'].astype(str)
bezrobocie_full
# Out:
#           kod                    pow   rok  liczba_bezrobotnych
# 0      201000   Powiat bolesławiecki  2023                  131
# 1      202000  Powiat dzierżoniowski  2023                  440
# 2      203000       Powiat głogowski  2023                  693
# 3      204000        Powiat górowski  2023                  537
# 4      205000        Powiat jaworski  2023                  663
# ...       ...                    ...   ...                  ...
# 3795  3217000         Powiat wałecki  2014                 1041
# 3796  3218000         Powiat łobeski  2014                 1067
# 3797  3261000     Powiat m. Koszalin  2014                 1993
# 3798  3262000     Powiat m. Szczecin  2014                 6549
# 3799  3263000  Powiat m. Świnoujście  2014                  252
#
# [3800 rows x 4 columns]

# %%
wynagrodzenie= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/Przeciętne miesięczne wynagrodzenia brutto.xlsx",sheet_name="TABLICA", header= None, skiprows=3, names=columns_names)

# %%
wynagrodzenie_2014 = wynagrodzenie.iloc[:, [0,1,2]]
wynagrodzenie_2014["rok"] = 2014
wynagrodzenie_2014 = wynagrodzenie_2014.iloc[:, [0,1,3,2]]
wynagrodzenie_2014.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2015 = wynagrodzenie.iloc[:, [0,1,3]]
wynagrodzenie_2015["rok"] = 2015
wynagrodzenie_2015 = wynagrodzenie_2015.iloc[:, [0,1,3,2]]
wynagrodzenie_2015.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2016 = wynagrodzenie.iloc[:, [0,1,4]]
wynagrodzenie_2016["rok"] = 2016
wynagrodzenie_2016 = wynagrodzenie_2016.iloc[:, [0,1,3,2]]
wynagrodzenie_2016.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2017 = wynagrodzenie.iloc[:, [0,1,5]]
wynagrodzenie_2017["rok"] = 2017
wynagrodzenie_2017 = wynagrodzenie_2017.iloc[:, [0,1,3,2]]
wynagrodzenie_2017.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2018 = wynagrodzenie.iloc[:, [0,1,6]]
wynagrodzenie_2018["rok"] = 2018
wynagrodzenie_2018 = wynagrodzenie_2018.iloc[:, [0,1,3,2]]
wynagrodzenie_2018.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2019 = wynagrodzenie.iloc[:, [0,1,7]]
wynagrodzenie_2019["rok"] = 2019
wynagrodzenie_2019 = wynagrodzenie_2019.iloc[:, [0,1,3,2]]
wynagrodzenie_2019.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2020 = wynagrodzenie.iloc[:, [0,1,8]]
wynagrodzenie_2020["rok"] = 2020
wynagrodzenie_2020 = wynagrodzenie_2020.iloc[:, [0,1,3,2]]
wynagrodzenie_2020.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2021 = wynagrodzenie.iloc[:, [0,1,9]]
wynagrodzenie_2021["rok"] = 2021
wynagrodzenie_2021 = wynagrodzenie_2021.iloc[:, [0,1,3,2]]
wynagrodzenie_2021.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2022 = wynagrodzenie.iloc[:, [0,1,10]]
wynagrodzenie_2022["rok"] = 2022
wynagrodzenie_2022 = wynagrodzenie_2022.iloc[:, [0,1,3,2]]
wynagrodzenie_2022.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]

wynagrodzenie_2023 = wynagrodzenie.iloc[:, [0,1,11]]
wynagrodzenie_2023["rok"] = 2023
wynagrodzenie_2023 = wynagrodzenie_2023.iloc[:, [0,1,3,2]]
wynagrodzenie_2023.columns = ["kod", "pow", "rok", "wielkosc_wynagrodzenia"]
# Out:
# <ipython-input-60-3b85d782a8db>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2014["rok"] = 2014
# <ipython-input-60-3b85d782a8db>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wynagrodzenie_2015["rok"] = 2015
# <ipython-input-60-3b85d782a8db>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
wynagrodzenie_full = polacz(wynagrodzenie_2023
   ,wynagrodzenie_2022,wynagrodzenie_2021,
wynagrodzenie_2020, wynagrodzenie_2019,
wynagrodzenie_2018,wynagrodzenie_2017,
wynagrodzenie_2016,wynagrodzenie_2015,wynagrodzenie_2014

)

# %%
wynagrodzenie_full["wielkosc_wynagrodzenia"]=wynagrodzenie_full["wielkosc_wynagrodzenia"].astype(int)
wynagrodzenie_full["kod"]=wynagrodzenie_full['kod'].astype(str)
wynagrodzenie_full
# Out:
#           kod                    pow   rok  wielkosc_wynagrodzenia
# 0      201000   Powiat bolesławiecki  2023                    6871
# 1      202000  Powiat dzierżoniowski  2023                    6459
# 2      203000       Powiat głogowski  2023                    6660
# 3      204000        Powiat górowski  2023                    6060
# 4      205000        Powiat jaworski  2023                    7059
# ...       ...                    ...   ...                     ...
# 3795  3217000         Powiat wałecki  2014                    3336
# 3796  3218000         Powiat łobeski  2014                    3289
# 3797  3261000     Powiat m. Koszalin  2014                    3568
# 3798  3262000     Powiat m. Szczecin  2014                    4176
# 3799  3263000  Powiat m. Świnoujście  2014                    4127
#
# [3800 rows x 4 columns]

# %%
dane_korelujace_powiaty=bezrobocie_full
dane_korelujace_powiaty= pd.merge(dane_korelujace_powiaty, wynagrodzenie_full, on=["rok","kod","pow"], how="outer")
dane_korelujace_powiaty
# Out:
#           kod                            pow   rok  liczba_bezrobotnych  \
# 0     1001000            Powiat bełchatowski  2014                 2739
# 1     1002000               Powiat kutnowski  2014                 3065
# 2     1003000                   Powiat łaski  2014                 1473
# 3     1004000                Powiat łęczycki  2014                 1629
# 4     1005000                 Powiat łowicki  2014                 1164
# ...       ...                            ...   ...                  ...
# 3795   810000                Powiat żagański  2023                  220
# 3796   811000                  Powiat żarski  2023                  473
# 3797   812000               Powiat wschowski  2023                  323
# 3798   861000  Powiat m. Gorzów Wielkopolski  2023                  186
# 3799   862000         Powiat m. Zielona Góra  2023                  459
#
#       wielkosc_wynagrodzenia
# 0                       5578
# 1                       3396
# ...

# %%
alkohol = pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/alkohol.xlsx",sheet_name="TABLICA", header= None, skiprows=3, names=columns_names, na_values="-")

# %%
alkohol_2014 = alkohol.iloc[:, [0,1,2]]
alkohol_2014["rok"] = 2014
alkohol_2014 = alkohol_2014.iloc[:, [0,1,3,2]]
alkohol_2014.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2015 = alkohol.iloc[:, [0,1,3]]
alkohol_2015["rok"] = 2015
alkohol_2015 = alkohol_2015.iloc[:, [0,1,3,2]]
alkohol_2015.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2016 = alkohol.iloc[:, [0,1,4]]
alkohol_2016["rok"] = 2016
alkohol_2016 = alkohol_2016.iloc[:, [0,1,3,2]]
alkohol_2016.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2017 = alkohol.iloc[:, [0,1,5]]
alkohol_2017["rok"] = 2017
alkohol_2017 = alkohol_2017.iloc[:, [0,1,3,2]]
alkohol_2017.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2018 = alkohol.iloc[:, [0,1,6]]
alkohol_2018["rok"] = 2018
alkohol_2018 = alkohol_2018.iloc[:, [0,1,3,2]]
alkohol_2018.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2019 = alkohol.iloc[:, [0,1,7]]
alkohol_2019["rok"] = 2019
alkohol_2019 = alkohol_2019.iloc[:, [0,1,3,2]]
alkohol_2019.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2020 = alkohol.iloc[:, [0,1,8]]
alkohol_2020["rok"] = 2020
alkohol_2020 = alkohol_2020.iloc[:, [0,1,3,2]]
alkohol_2020.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2021 = alkohol.iloc[:, [0,1,9]]
alkohol_2021["rok"] = 2021
alkohol_2021 = alkohol_2021.iloc[:, [0,1,3,2]]
alkohol_2021.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2022 = alkohol.iloc[:, [0,1,10]]
alkohol_2022["rok"] = 2022
alkohol_2022 = alkohol_2022.iloc[:, [0,1,3,2]]
alkohol_2022.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]

alkohol_2023 = alkohol.iloc[:, [0,1,11]]
alkohol_2023["rok"] = 2023
alkohol_2023 = alkohol_2023.iloc[:, [0,1,3,2]]
alkohol_2023.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_alkoholowymi"]
# Out:
# <ipython-input-65-7cd0a85a09b1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alkohol_2014["rok"] = 2014
# <ipython-input-65-7cd0a85a09b1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alkohol_2015["rok"] = 2015
# <ipython-input-65-7cd0a85a09b1>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
alkohol_full = polacz(alkohol_2023
   ,alkohol_2022,alkohol_2021,
alkohol_2020, alkohol_2019,
alkohol_2018,alkohol_2017,
alkohol_2016,alkohol_2015,alkohol_2014

)

# %%
alkohol_full["kod"]=alkohol_full['kod'].astype(str)
alkohol_full
# Out:
#          kod                  woj   rok  \
# 0     200000         DOLNOŚLĄSKIE  2023
# 1     400000   KUJAWSKO-POMORSKIE  2023
# 2     600000            LUBELSKIE  2023
# 3     800000             LUBUSKIE  2023
# 4    1000000              ŁÓDZKIE  2023
# ..       ...                  ...   ...
# 155  2400000              ŚLĄSKIE  2014
# 156  2600000       ŚWIĘTOKRZYSKIE  2014
# 157  2800000  WARMIŃSKO-MAZURSKIE  2014
# 158  3000000        WIELKOPOLSKIE  2014
# 159  3200000   ZACHODNIOPOMORSKIE  2014
#
#      liczba_osob_z_zaburzeniami_alkoholowymi
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 155                                  20851.0
# 156                                   6285.0
# 157                                   6928.0
# ...

# %%
srodki_psychoaktywne = pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/środki_psychoaktywne.xlsx",sheet_name="TABLICA", header= None, skiprows=3, names=columns_names, na_values="-")

# %%
srodki_psychoaktywne_2014 = srodki_psychoaktywne.iloc[:, [0,1,2]]
srodki_psychoaktywne_2014["rok"] = 2014
srodki_psychoaktywne_2014 = srodki_psychoaktywne_2014.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2014.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2015 = srodki_psychoaktywne.iloc[:, [0,1,3]]
srodki_psychoaktywne_2015["rok"] = 2015
srodki_psychoaktywne_2015 = srodki_psychoaktywne_2015.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2015.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2016 = srodki_psychoaktywne.iloc[:, [0,1,4]]
srodki_psychoaktywne_2016["rok"] = 2016
srodki_psychoaktywne_2016 = srodki_psychoaktywne_2016.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2016.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2017 = srodki_psychoaktywne.iloc[:, [0,1,5]]
srodki_psychoaktywne_2017["rok"] = 2017
srodki_psychoaktywne_2017 = srodki_psychoaktywne_2017.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2017.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2018 = srodki_psychoaktywne.iloc[:, [0,1,6]]
srodki_psychoaktywne_2018["rok"] = 2018
srodki_psychoaktywne_2018 = srodki_psychoaktywne_2018.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2018.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2019 = srodki_psychoaktywne.iloc[:, [0,1,7]]
srodki_psychoaktywne_2019["rok"] = 2019
srodki_psychoaktywne_2019 = srodki_psychoaktywne_2019.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2019.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2020 = srodki_psychoaktywne.iloc[:, [0,1,8]]
srodki_psychoaktywne_2020["rok"] = 2020
srodki_psychoaktywne_2020 = srodki_psychoaktywne_2020.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2020.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2021 = srodki_psychoaktywne.iloc[:, [0,1,9]]
srodki_psychoaktywne_2021["rok"] = 2021
srodki_psychoaktywne_2021 = srodki_psychoaktywne_2021.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2021.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2022 = srodki_psychoaktywne.iloc[:, [0,1,10]]
srodki_psychoaktywne_2022["rok"] = 2022
srodki_psychoaktywne_2022 = srodki_psychoaktywne_2022.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2022.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]

srodki_psychoaktywne_2023 = srodki_psychoaktywne.iloc[:, [0,1,11]]
srodki_psychoaktywne_2023["rok"] = 2023
srodki_psychoaktywne_2023 = srodki_psychoaktywne_2023.iloc[:, [0,1,3,2]]
srodki_psychoaktywne_2023.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_srodki_psychoaktywne"]
# Out:
# <ipython-input-69-4b7c6983b186>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   srodki_psychoaktywne_2014["rok"] = 2014
# <ipython-input-69-4b7c6983b186>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   srodki_psychoaktywne_2015["rok"] = 2015
# <ipython-input-69-4b7c6983b186>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
srodki_psychoaktywne_full = polacz(srodki_psychoaktywne_2023
   ,srodki_psychoaktywne_2022,srodki_psychoaktywne_2021,
srodki_psychoaktywne_2020, srodki_psychoaktywne_2019,
srodki_psychoaktywne_2018,srodki_psychoaktywne_2017,
srodki_psychoaktywne_2016,srodki_psychoaktywne_2015,srodki_psychoaktywne_2014

)

# %%
srodki_psychoaktywne_full["kod"]=srodki_psychoaktywne_full['kod'].astype(str)
srodki_psychoaktywne_full
# Out:
#          kod                  woj   rok  \
# 0     200000         DOLNOŚLĄSKIE  2023
# 1     400000   KUJAWSKO-POMORSKIE  2023
# 2     600000            LUBELSKIE  2023
# 3     800000             LUBUSKIE  2023
# 4    1000000              ŁÓDZKIE  2023
# ..       ...                  ...   ...
# 155  2400000              ŚLĄSKIE  2014
# 156  2600000       ŚWIĘTOKRZYSKIE  2014
# 157  2800000  WARMIŃSKO-MAZURSKIE  2014
# 158  3000000        WIELKOPOLSKIE  2014
# 159  3200000   ZACHODNIOPOMORSKIE  2014
#
#      liczba_osob_z_zaburzeniami_srodki_psychoaktywne
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 155                                           3078.0
# ...

# %%
zaburzenia_psychiczne= pd.read_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/raw_data/zaburzenia_psychiczne.xlsx",sheet_name="TABLICA", header= None, skiprows=3, names=columns_names, na_values="-")

# %%
zaburzenia_psychiczne_2014 = zaburzenia_psychiczne.iloc[:, [0,1,2]]
zaburzenia_psychiczne_2014["rok"] = 2014
zaburzenia_psychiczne_2014 = zaburzenia_psychiczne_2014.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2014.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2015 = zaburzenia_psychiczne.iloc[:, [0,1,3]]
zaburzenia_psychiczne_2015["rok"] = 2015
zaburzenia_psychiczne_2015 = zaburzenia_psychiczne_2015.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2015.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2016 = zaburzenia_psychiczne.iloc[:, [0,1,4]]
zaburzenia_psychiczne_2016["rok"] = 2016
zaburzenia_psychiczne_2016 = zaburzenia_psychiczne_2016.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2016.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2017 = zaburzenia_psychiczne.iloc[:, [0,1,5]]
zaburzenia_psychiczne_2017["rok"] = 2017
zaburzenia_psychiczne_2017 = zaburzenia_psychiczne_2017.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2017.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2018 = zaburzenia_psychiczne.iloc[:, [0,1,6]]
zaburzenia_psychiczne_2018["rok"] = 2018
zaburzenia_psychiczne_2018 = zaburzenia_psychiczne_2018.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2018.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2019 = zaburzenia_psychiczne.iloc[:, [0,1,7]]
zaburzenia_psychiczne_2019["rok"] = 2019
zaburzenia_psychiczne_2019 = zaburzenia_psychiczne_2019.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2019.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2020 = zaburzenia_psychiczne.iloc[:, [0,1,8]]
zaburzenia_psychiczne_2020["rok"] = 2020
zaburzenia_psychiczne_2020 = zaburzenia_psychiczne_2020.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2020.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2021 = zaburzenia_psychiczne.iloc[:, [0,1,9]]
zaburzenia_psychiczne_2021["rok"] = 2021
zaburzenia_psychiczne_2021 = zaburzenia_psychiczne_2021.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2021.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2022 = zaburzenia_psychiczne.iloc[:, [0,1,10]]
zaburzenia_psychiczne_2022["rok"] = 2022
zaburzenia_psychiczne_2022 = zaburzenia_psychiczne_2022.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2022.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]

zaburzenia_psychiczne_2023 = zaburzenia_psychiczne.iloc[:, [0,1,11]]
zaburzenia_psychiczne_2023["rok"] = 2023
zaburzenia_psychiczne_2023 = zaburzenia_psychiczne_2023.iloc[:, [0,1,3,2]]
zaburzenia_psychiczne_2023.columns = ["kod", "woj", "rok", "liczba_osob_z_zaburzeniami_psychicznymi"]
# Out:
# <ipython-input-73-77b365e4560a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zaburzenia_psychiczne_2014["rok"] = 2014
# <ipython-input-73-77b365e4560a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zaburzenia_psychiczne_2015["rok"] = 2015
# <ipython-input-73-77b365e4560a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
zaburzenia_psychiczne_full = polacz(zaburzenia_psychiczne_2023
   ,zaburzenia_psychiczne_2022,zaburzenia_psychiczne_2021,
zaburzenia_psychiczne_2020, zaburzenia_psychiczne_2019,
zaburzenia_psychiczne_2018,zaburzenia_psychiczne_2017,
zaburzenia_psychiczne_2016,zaburzenia_psychiczne_2015,zaburzenia_psychiczne_2014

)

# %%
zaburzenia_psychiczne_full["kod"]=zaburzenia_psychiczne_full['kod'].astype(str)
zaburzenia_psychiczne_full
# Out:
#          kod                  woj   rok  \
# 0     200000         DOLNOŚLĄSKIE  2023
# 1     400000   KUJAWSKO-POMORSKIE  2023
# 2     600000            LUBELSKIE  2023
# 3     800000             LUBUSKIE  2023
# 4    1000000              ŁÓDZKIE  2023
# ..       ...                  ...   ...
# 155  2400000              ŚLĄSKIE  2014
# 156  2600000       ŚWIĘTOKRZYSKIE  2014
# 157  2800000  WARMIŃSKO-MAZURSKIE  2014
# 158  3000000        WIELKOPOLSKIE  2014
# 159  3200000   ZACHODNIOPOMORSKIE  2014
#
#      liczba_osob_z_zaburzeniami_psychicznymi
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 155                                 141644.0
# 156                                  42955.0
# 157                                  34637.0
# ...

# %%
dane_korelujace_wojewodztwa=alkohol_full
dane_korelujace_wojewodztwa = pd.merge(dane_korelujace_wojewodztwa,zaburzenia_psychiczne_full, on =["rok","kod","woj"],how ="outer")
dane_korelujace_wojewodztwa = pd.merge(dane_korelujace_wojewodztwa,srodki_psychoaktywne_full, on =["rok","kod","woj"],how ="outer")

# %%
dane_korelujace_wojewodztwa
# Out:
#          kod                 woj   rok  \
# 0    1000000             ŁÓDZKIE  2014
# 1    1200000         MAŁOPOLSKIE  2014
# 2    1400000         MAZOWIECKIE  2014
# 3    1600000            OPOLSKIE  2014
# 4    1800000        PODKARPACKIE  2014
# ..       ...                 ...   ...
# 155  3000000       WIELKOPOLSKIE  2023
# 156  3200000  ZACHODNIOPOMORSKIE  2023
# 157   400000  KUJAWSKO-POMORSKIE  2023
# 158   600000           LUBELSKIE  2023
# 159   800000            LUBUSKIE  2023
#
#      liczba_osob_z_zaburzeniami_alkoholowymi  \
# 0                                    14208.0
# 1                                    11749.0
# 2                                    22251.0
# 3                                     3518.0
# 4                                     9623.0
# ..                                       ...
# 155                                      NaN
# 156                                      NaN
# 157                                      NaN
# ...

# %%
dane_korelujace_powiaty.to_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/dane_korelujace_powiaty.xlsx", sheet_name= "dane_korelujace_powiaty" ,index=False)

# %%
dane_korelujace_wojewodztwa.to_excel("/content/drive/MyDrive/praca_licencjacka/Dane korelujace/dane_korelujace_wojewodztwa.xlsx", sheet_name= "dane_korelujace_wojewodztwa" ,index=False)
